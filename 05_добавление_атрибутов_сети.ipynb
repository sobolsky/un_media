# %% [markdown]
# # 05 Добавлени атрибутов сети

# %%
import numpy as np
import pandas as pd
import networkx as nx
from matplotlib.pyplot import figure

# %% [markdown]
# ## 1. Добавление координат в сеть

# %%
country_attr_table = pd.read_csv('country_attr_table.csv')
country_attr_table
# Out:
#                                 Country Country index   latitude   longitude
# 0                           AFGHANISTAN            AF  33.939110   67.709953
# 1                               ALBANIA            AL  41.153332   20.168331
# 2                               ALGERIA            DZ  28.033886    1.659626
# 3                               ANDORRA            AD  42.546245    1.601554
# 4                                ANGOLA            AO -11.202692   17.873887
# 5                   ANTIGUA AND BARBUDA            AG  17.060816  -61.796428
# 6                             ARGENTINA            AR -38.416097  -63.616672
# 7                               ARMENIA            AM  40.069099   45.038189
# 8                             AUSTRALIA            AU -25.274398  133.775136
# 9                               AUSTRIA            AT  47.516231   14.550072
# 10                           AZERBAIJAN            AZ  40.143105   47.576927
# ...

# %%
nodes_array = []

for index in range (0, len(country_attr_table)):
    nodes_array.append(
        (
            country_attr_table['Country'][index], 
         {
             #'Country index': country_attr_table['Country index'][index],
             'latitude': country_attr_table['latitude'][index],
             'longitude': country_attr_table['longitude'][index]
         }
        ) 
    )
    
# net_table_weight.apply(lambda x: G.add_edge(x[0], x[1], weight= x[2]), axis=1)

# %%
G = nx.Graph()
G.add_nodes_from(nodes_array)

# %%
len(G)
# Out:
# 193

# %%
figure(figsize=(20, 10))
nx.draw_networkx(G)

# %%
G2 = nx.read_gexf('UN_UKRAINE--POLITICAL_CONDITIONS_.gexf')

# %%
len(G2)
# Out:
# 193

# %%
figure(figsize=(20, 10))
nx.draw_networkx(G)

# %%
R = nx.compose(G, G2)

# %%
R.nodes(data=True)
# Out:
# NodeDataView({'AFGHANISTAN': {'latitude': 33.93911, 'longitude': 67.709953, 'label': 'AFGHANISTAN'}, 'ALBANIA': {'latitude': 41.153332, 'longitude': 20.168331, 'label': 'ALBANIA'}, 'ALGERIA': {'latitude': 28.033886, 'longitude': 1.6596259999999998, 'label': 'ALGERIA'}, 'ANDORRA': {'latitude': 42.546245, 'longitude': 1.6015540000000001, 'label': 'ANDORRA'}, 'ANGOLA': {'latitude': -11.202691999999999, 'longitude': 17.873887, 'label': 'ANGOLA'}, 'ANTIGUA AND BARBUDA': {'latitude': 17.060816, 'longitude': -61.79642800000001, 'label': 'ANTIGUA AND BARBUDA'}, 'ARGENTINA': {'latitude': -38.416097, 'longitude': -63.616671999999994, 'label': 'ARGENTINA'}, 'ARMENIA': {'latitude': 40.069099, 'longitude': 45.038189, 'label': 'ARMENIA'}, 'AUSTRALIA': {'latitude': -25.274398, 'longitude': 133.775136, 'label': 'AUSTRALIA'}, 'AUSTRIA': {'latitude': 47.516231, 'longitude': 14.550072, 'label': 'AUSTRIA'}, 'AZERBAIJAN': {'latitude': 40.143105, 'longitude': 47.57692700000001, 'label': 'AZERBAIJAN'}, 'BA
# ...

# %%
R.edges(data=True)
# Out:
# EdgeDataView([('AFGHANISTAN', 'ALBANIA', {'id': '0', 'weight': 4.0}), ('AFGHANISTAN', 'ANDORRA', {'id': '1', 'weight': 4.0}), ('AFGHANISTAN', 'ANGOLA', {'id': '2', 'weight': 1.0}), ('AFGHANISTAN', 'ANTIGUA AND BARBUDA', {'id': '3', 'weight': 3.0}), ('AFGHANISTAN', 'ARGENTINA', {'id': '4', 'weight': 4.0}), ('AFGHANISTAN', 'AUSTRALIA', {'id': '5', 'weight': 4.0}), ('AFGHANISTAN', 'AUSTRIA', {'id': '6', 'weight': 4.0}), ('AFGHANISTAN', 'BAHAMAS', {'id': '7', 'weight': 3.0}), ('AFGHANISTAN', 'BAHRAIN', {'id': '8', 'weight': 3.0}), ('AFGHANISTAN', 'BANGLADESH', {'id': '9', 'weight': 2.0}), ('AFGHANISTAN', 'BARBADOS', {'id': '10', 'weight': 3.0}), ('AFGHANISTAN', 'BELGIUM', {'id': '11', 'weight': 4.0}), ('AFGHANISTAN', 'BELIZE', {'id': '12', 'weight': 3.0}), ('AFGHANISTAN', 'BENIN', {'id': '13', 'weight': 4.0}), ('AFGHANISTAN', 'BHUTAN', {'id': '14', 'weight': 3.0}), ('AFGHANISTAN', 'BOSNIA AND HERZEGOVINA', {'id': '15', 'weight': 4.0}), ('AFGHANISTAN', 'BOTSWANA', {'id': '16', 'weight': 2
# ...

# %%
nx.write_gexf(R, 'UN_UKRAINE--POLITICAL_CONDITIONS_attr.gexf')

# %% [markdown]
# ## 2. Сбор данных для узлов

# %% [markdown]
# ### 2.1 Population and migration

# %% [markdown]
# #### 2.1.1 Population, surface area and density

# %%
#syb65__T02_table = pd.read_csv('reports/syb66__T02.csv')
syb65__T02_table = pd.read_csv('reports/syb66__T02.csv', encoding='ISO-8859-1')

syb65__T02_table
# Out:
#                       T02 Population, density and surface area Unnamed: 2  \
# 0     Region/Country/Area                                  NaN       Year
# 1                       1        Total, all countries or areas       2010
# 2                       1        Total, all countries or areas       2010
# 3                       1        Total, all countries or areas       2010
# 4                       1        Total, all countries or areas       2010
# ...                   ...                                  ...        ...
# 7648                  722                                 SIDS       2022
# 7649                  722                                 SIDS       2022
# 7650                  722                                 SIDS       2022
# 7651                  722                                 SIDS       2022
# 7652                  722                                 SIDS       2022
#
#                                              Unnamed: 3 Unnamed: 4  \
# ...

# %%
#syb65__T02_table = pd.read_csv('reports/syb65__T02.csv')
syb65__T02_table[
    (syb65__T02_table['Unnamed: 2'] == '2022') 
    & 
    (syb65__T02_table['Population, density and surface area'] == 'Zimbabwe')
    &
    (
        (syb65__T02_table['Unnamed: 3'] == 'Population mid-year estimates (millions)')
        |
        (syb65__T02_table['Unnamed: 3'] == 'Population density')
    )  
]


#.iloc[:50]
# Out:
#       T02 Population, density and surface area Unnamed: 2  \
# 7583  716                             Zimbabwe       2022
# 7589  716                             Zimbabwe       2022
#
#                                     Unnamed: 3 Unnamed: 4  \
# 7583  Population mid-year estimates (millions)      16.32
# 7589                        Population density       42.2
#
#                                           Unnamed: 5  \
# 7583  Projected estimate (medium fertility variant).
# 7589  Projected estimate (medium fertility variant).
#
#                                              Unnamed: 6
# 7583  United Nations Population Division, New York, ...
# 7589  United Nations Population Division, New York, ...

# %%
population_table = syb65__T02_table[
    (syb65__T02_table['Unnamed: 2'] == '2022') 
    &
    (
        (syb65__T02_table['Unnamed: 3'] == 'Population mid-year estimates (millions)')
    )  
][31:].drop(
    ['T02', 'Unnamed: 2', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 3'], axis = 1
).rename(
    columns={
        'Population, density and surface area': 'Country', 
        'Unnamed: 4': 'Population mid-year estimates (millions), 2022'
    }
)

#population_table.set_index(
#    'Country', inplace = True
#)

population_table
# Out:
#              Country Population mid-year estimates (millions), 2022
# 906      Afghanistan                                          41.13
# 935          Albania                                           2.84
# 964          Algeria                                          44.90
# 993   American Samoa                                           0.04
# 1022         Andorra                                           0.08
# ...              ...                                            ...
# 7554          Zambia                                          20.02
# 7583        Zimbabwe                                          16.32
# 7604           LLDCs                                         563.80
# 7625            LDC§                                       1,125.18
# 7646            SIDS                                          74.36
#
# [236 rows x 2 columns]

# %%
population_table['Country'] = [x.upper() for x in population_table['Country']]

# %%
population_table.set_index(
    'Country', inplace = True
)

# %%
population_table[100:]
# Out:
#             Population mid-year estimates (millions), 2022
# Country
# IRELAND                                               5.02
# ISLE OF MAN                                           0.08
# ISRAEL                                                9.04
# ITALY                                                59.04
# JAMAICA                                               2.83
# ...                                                    ...
# ZAMBIA                                               20.02
# ZIMBABWE                                             16.32
# LLDCS                                               563.80
# LDC§                                              1,125.18
# SIDS                                                 74.36
#
# [136 rows x 1 columns]

# %%
population_table.loc[['BOLIVIA (PLURIN. STATE OF)'], list(population_table.columns)]
# Out:
#                            Population mid-year estimates (millions), 2022
# Country
# BOLIVIA (PLURIN. STATE OF)                                          12.22

# %% [markdown]
# #### Замена названия стран на стандартные

# %%
#population_table.rename(index={'BOLIVIA (PLURIN. STATE OF)':'BOLIVIA (PLURINATIONAL STATE OF)'}, inplace = True)

# %%
population_table.loc[['UNITED STATES OF AMERICA'], list(population_table.columns)]
#list(population_table.columns)
# Out:
#                          Population mid-year estimates (millions), 2022
# Country
# UNITED STATES OF AMERICA                                         338.29

# %%
def changing_names_of_index(table_index, right_index):
     population_table.rename(
        index={table_index: right_index}, 
        inplace = True
    )

# %%
changing_attr_arr = [
    ['BOLIVIA (PLURIN. STATE OF)', 'BOLIVIA (PLURINATIONAL STATE OF)'],
    ["CÔTE D'IVOIRE", 'CÔTE D’IVOIRE'],
    ["DEM. PEOPLE'S REP. KOREA", "DEMOCRATIC PEOPLE'S REPUBLIC OF KOREA"],
    ["DEM. REP. OF THE CONGO", 'DEMOCRATIC REPUBLIC OF THE CONGO'],
    ["LAO PEOPLE'S DEM. REP.", "LAO PEOPLE'S DEMOCRATIC REPUBLIC"],
    ['MICRONESIA (FED. STATES OF)', 'MICRONESIA (FEDERATED STATES OF)'],
    ['SAINT VINCENT & GRENADINES', 'SAINT VINCENT AND THE GRENADINES'],
    ['TÜRKIYE', 'TURKIYE'],
    ['UNITED REP. OF TANZANIA', 'UNITED REPUBLIC OF TANZANIA'],
    ['UNITED STATES OF AMERICA', 'UNITED STATES'],
    ['VENEZUELA (BOLIV. REP. OF)', 'VENEZUELA (BOLIVARIAN REPUBLIC OF)']
    
]

for item in changing_attr_arr:
    changing_names_of_index(item[0], item[1])
    
#population_table.loc[[changing_attr_arr[-1][1]], list(population_table.columns)]

# %%
#population_table[population_table['Population mid-year estimates (millions), 2022'].isna()]
population_table[
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d842e3e2d025> in <module>
#       1 #population_table[population_table['Population mid-year estimates (millions), 2022'].isna()]
# ----> 2 population_table
#
# NameError: name 'population_table' is not defined

# %%
country_attr_table.set_index('Country', inplace = True)

# %%
#country_attr_table.dropna(
#    subset=['latitude']
#)
country_attr_table[160:180]
# Out:
#                      Country index   latitude   longitude
# Country
# SOUTH AFRICA                    ZA -30.559482   22.937506
# SOUTH SUDAN                     SD  12.862807   30.217636
# SPAIN                           ES  40.463667   -3.749220
# SRI LANKA                       LK   7.873054   80.771797
# SUDAN                           SD  12.862807   30.217636
# SURINAME                        SR   3.919305  -56.027783
# SWEDEN                          SE  60.128161   18.643501
# SWITZERLAND                     CH  46.818188    8.227512
# SYRIAN ARAB REPUBLIC            SY  34.802075   38.996815
# TAJIKISTAN                      TJ  38.861034   71.276093
# THAILAND                        TH  15.870032  100.992541
# TIMOR-LESTE                     TL  -8.874217  125.727539
# TOGO                            TG   8.619543    0.824782
# TONGA                           TO -21.178986 -175.198242
# TRINIDAD AND TOBAGO             TT  10.691803  -61.222503
# ...

# %%
country_attr_table[country_attr_table['Country index'].isna()]
# Out:
# Empty DataFrame
# Columns: [Country index, latitude, longitude]
# Index: []

# %%
country_attr_table_1 = pd.merge(
    country_attr_table, 
    population_table, 
    how='outer', 
    left_index=True, 
    right_index=True
)#.dropna(
    #subset=['latitude']
#).to_csv(
    #'country_attr_table.csv'
#) 
country_attr_table_1
# Out:
#                           Country index   latitude  longitude  \
# Country
# AFGHANISTAN                          AF  33.939110  67.709953
# ALBANIA                              AL  41.153332  20.168331
# ALGERIA                              DZ  28.033886   1.659626
# AMERICAN SAMOA                      NaN        NaN        NaN
# ANDORRA                              AD  42.546245   1.601554
# ...                                 ...        ...        ...
# WALLIS AND FUTUNA ISLANDS           NaN        NaN        NaN
# WESTERN SAHARA                      NaN        NaN        NaN
# YEMEN                                YE  15.552727  48.516388
# ZAMBIA                               ZM -13.133897  27.849332
# ZIMBABWE                             ZW -19.015438  29.154857
#
#                           Population mid-year estimates (millions), 2022
# Country
# AFGHANISTAN                                                        41.13
# ...

# %%
country_attr_table_1[
    country_attr_table_1['Country index'].notna()
    &
    country_attr_table_1['Population mid-year estimates (millions), 2022'].isna()
]
# Out:
#               Country index   latitude  longitude  \
# Country
# CÔTE D'IVOIRE            CI   7.539989  -5.547080
# NETHERLANDS              NL  52.132633   5.291266
# TÜRKIYE                  TR  38.963745  35.243322
#
#               Population mid-year estimates (millions), 2022
# Country
# CÔTE D'IVOIRE                                            NaN
# NETHERLANDS                                              NaN
# TÜRKIYE                                                  NaN

# %%
#country_attr_table_1[
#    country_attr_table_1['Country index'].isna()
#    &
#    country_attr_table_1['Population mid-year estimates (millions), 2022'].notna()
#]

# %%
country_attr_table_1[
    country_attr_table_1['Country index'].notna()
].to_csv('country_attr_table_1.csv')

# %%
country_attr_table_1 = pd.read_csv('country_attr_table_1.csv', index_col='Country')
country_attr_table_1
# Out:
#                                    Country index   latitude   longitude  \
# Country
# AFGHANISTAN                                   AF  33.939110   67.709953
# ALBANIA                                       AL  41.153332   20.168331
# ALGERIA                                       DZ  28.033886    1.659626
# ANDORRA                                       AD  42.546245    1.601554
# ANGOLA                                        AO -11.202692   17.873887
# ...                                          ...        ...         ...
# VENEZUELA (BOLIVARIAN REPUBLIC OF)            VE   6.423750  -66.589730
# VIET NAM                                      VN  14.058324  108.277199
# YEMEN                                         YE  15.552727   48.516388
# ZAMBIA                                        ZM -13.133897   27.849332
# ZIMBABWE                                      ZW -19.015438   29.154857
#
#                                    Population mid-year estimates (millions), 2022
# Country
# ...

# %%
country_attr_table_1[
    country_attr_table_1['Country index'].notna()
    &
    country_attr_table_1['Population mid-year estimates (millions), 2022'].isna()
]
# Out:
#         Country index   latitude  longitude  \
# Country
# TÜRKIYE            TR  38.963745  35.243322
#
#         Population mid-year estimates (millions), 2022
# Country
# TÜRKIYE                                            NaN

# %% [markdown]
# ### 2.2 Energy

# %% [markdown]
# #### 2.2.1 Production, trade and supply of energy

# %%
country_attr_table_1 = pd.read_csv('country_attr_table_1.csv', index_col='Country')

#country_attr_table.drop(
#    ['Population mid-year estimates (millions), 2022'],
#    axis = 1,
#    inplace = True
#)
country_attr_table_1
# Out:
#                                    Country index   latitude   longitude  \
# Country
# AFGHANISTAN                                   AF  33.939110   67.709953
# ALBANIA                                       AL  41.153332   20.168331
# ALGERIA                                       DZ  28.033886    1.659626
# ANDORRA                                       AD  42.546245    1.601554
# ANGOLA                                        AO -11.202692   17.873887
# ...                                          ...        ...         ...
# VENEZUELA (BOLIVARIAN REPUBLIC OF)            VE   6.423750  -66.589730
# VIET NAM                                      VN  14.058324  108.277199
# YEMEN                                         YE  15.552727   48.516388
# ZAMBIA                                        ZM -13.133897   27.849332
# ZIMBABWE                                      ZW -19.015438   29.154857
#
#                                    Population mid-year estimates (millions), 2022
# Country
# ...

# %%
syb65__T23_table = pd.read_csv('reports/syb65__T23.csv')
syb65__T23_table = pd.read_csv('reports/syb66__T23.csv', encoding='ISO-8859-1')

syb65__T23_table
# Out:
#                       T23 Production, trade and supply of energy Unnamed: 2  \
# 0     Region/Country/Area                                    NaN       Year
# 1                       1          Total, all countries or areas       1995
# 2                       1          Total, all countries or areas       2000
# 3                       1          Total, all countries or areas       2005
# 4                       1          Total, all countries or areas       2010
# ...                   ...                                    ...        ...
# 8580                  716                               Zimbabwe       2010
# 8581                  716                               Zimbabwe       2015
# 8582                  716                               Zimbabwe       2018
# 8583                  716                               Zimbabwe       2019
# 8584                  716                               Zimbabwe       2020
#
# ...

# %%
energy_table = syb65__T23_table[
    (syb65__T23_table['Unnamed: 2'] == '2020') 
    #& 
    #(syb65__T23_table['Production, trade and supply of energy'] == 'Zimbabwe')
    &
    (
        (syb65__T23_table['Unnamed: 3'] == 'Primary energy production (petajoules)')
    )    
][7:].drop(
    ['T23', 'Unnamed: 2', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 3'], axis = 1
).rename(
    columns={
        'Production, trade and supply of energy': 'Country', 
        'Unnamed: 4': 'Primary energy production (petajoules), 2020'
    }
)

energy_table
# Out:
#                         Country Primary energy production (petajoules), 2020
# 288                 Afghanistan                                           71
# 328                     Albania                                           63
# 367                     Algeria                                        5,506
# 403              American Samoa                                            0
# 435                     Andorra                                            1
# ...                         ...                                          ...
# 8406                   Viet Nam                                        2,509
# 8446  Wallis and Futuna Islands                                            0
# 8478                      Yemen                                          164
# 8513                     Zambia                                          405
# 8553                   Zimbabwe                                          377
#
# [222 rows x 2 columns]

# %%
energy_table.loc[energy_table['Country'] == 'China']
# Out:
#      Country Primary energy production (petajoules), 2020
# 1820   China                                      111,744

# %%
energy_table.loc[energy_table['Country'] == 'Russian Federation']
# Out:
#                  Country Primary energy production (petajoules), 2020
# 6566  Russian Federation                                       60,041

# %%
energy_table[energy_table['Primary energy production (petajoules), 2020'].isna()]
# Out:
# Empty DataFrame
# Columns: [Country, Primary energy production (petajoules), 2020]
# Index: []

# %%
energy_table[energy_table['Country'] == 'Monaco']
# Out:
# Empty DataFrame
# Columns: [Country, Primary energy production (petajoules), 2020]
# Index: []

# %%
energy_table.iloc[]
# Out:
#   File "<ipython-input-44-d4385dbf013e>", line 1
#     energy_table.iloc[]
#                       ^
# SyntaxError: invalid syntax

# %%
country_attr_table_2[
    country_attr_table_2['Country index'].notna()
    &
    country_attr_table_2['Primary energy production (petajoules), 2019'].isna()
]
# Out:
#                                       Country index   latitude   longitude  \
# Country
# BOLIVIA (PLURINATIONAL STATE OF)                 BO -16.290154  -63.588653
# CÔTE D'IVOIRE                                    CI   7.539989   -5.547080
# DEMOCRATIC PEOPLE'S REPUBLIC OF KOREA            KP  40.339852  127.510093
# DEMOCRATIC REPUBLIC OF THE CONGO                 CD  -4.038333   21.758664
# LAO PEOPLE'S DEMOCRATIC REPUBLIC                 LA  19.856270  102.495496
# MICRONESIA (FEDERATED STATES OF)                 FM   7.425554  150.550812
# MONACO                                           MC  43.750298    7.412841
# SAINT VINCENT AND THE GRENADINES                 VC  12.984305  -61.287228
# SAN MARINO                                       SM  43.942360   12.457777
# UNITED REPUBLIC OF TANZANIA                      TZ  -6.369028   34.888822
# UNITED STATES                                    US  37.090240  -95.712891
# ...

# %%
energy_table['Country'] = [x.upper() for x in energy_table['Country']]

# %%
energy_table.set_index(
    'Country', inplace = True
)
energy_table
# Out:
#                           Primary energy production (petajoules), 2020
# Country
# AFGHANISTAN                                                         71
# ALBANIA                                                             63
# ALGERIA                                                          5,506
# AMERICAN SAMOA                                                       0
# ANDORRA                                                              1
# ...                                                                ...
# VIET NAM                                                         2,509
# WALLIS AND FUTUNA ISLANDS                                            0
# YEMEN                                                              164
# ZAMBIA                                                             405
# ZIMBABWE                                                           377
#
# [222 rows x 1 columns]

# %%
energy_table[energy_table['Primary energy production (petajoules), 2020'].isna()]
# Out:
# Empty DataFrame
# Columns: [Primary energy production (petajoules), 2020]
# Index: []

# %%
country_attr_table_1
# Out:
#                                    Country index   latitude   longitude  \
# Country
# AFGHANISTAN                                   AF  33.939110   67.709953
# ALBANIA                                       AL  41.153332   20.168331
# ALGERIA                                       DZ  28.033886    1.659626
# ANDORRA                                       AD  42.546245    1.601554
# ANGOLA                                        AO -11.202692   17.873887
# ...                                          ...        ...         ...
# VENEZUELA (BOLIVARIAN REPUBLIC OF)            VE   6.423750  -66.589730
# VIET NAM                                      VN  14.058324  108.277199
# YEMEN                                         YE  15.552727   48.516388
# ZAMBIA                                        ZM -13.133897   27.849332
# ZIMBABWE                                      ZW -19.015438   29.154857
#
#                                    Population mid-year estimates (millions), 2022
# Country
# ...

# %%
country_attr_table_2 = pd.merge(
    country_attr_table_1, 
    energy_table, 
    how='outer', 
    left_index=True, 
    right_index=True
)#.dropna(
    #subset=['latitude']
#)#.to_csv(
    #'country_attr_table.csv'
#)

# %%
country_attr_table_2
# Out:
#                           Country index   latitude   longitude  \
# Country
# AFGHANISTAN                          AF  33.939110   67.709953
# ALBANIA                              AL  41.153332   20.168331
# ALGERIA                              DZ  28.033886    1.659626
# AMERICAN SAMOA                      NaN        NaN         NaN
# ANDORRA                              AD  42.546245    1.601554
# ...                                 ...        ...         ...
# VIET NAM                             VN  14.058324  108.277199
# WALLIS AND FUTUNA ISLANDS           NaN        NaN         NaN
# YEMEN                                YE  15.552727   48.516388
# ZAMBIA                               ZM -13.133897   27.849332
# ZIMBABWE                             ZW -19.015438   29.154857
#
#                           Population mid-year estimates (millions), 2022  \
# Country
# AFGHANISTAN                                                        41.13
# ...

# %%
energy_table[energy_table['Primary energy production (petajoules), 2020'].isna()]
# Out:
# Empty DataFrame
# Columns: [Primary energy production (petajoules), 2020]
# Index: []

# %%
energy_table[150:160]
# Out:
#                           Primary energy production (petajoules), 2019
# Country
# OTHER NON-SPECIFIED AREAS                                          475
# PAKISTAN                                                         2,366
# PALAU                                                                0
# PANAMA                                                              34
# PAPUA NEW GUINEA                                                   240
# PARAGUAY                                                           309
# PERU                                                               964
# PHILIPPINES                                                      1,274
# POLAND                                                           2,484
# PORTUGAL                                                           246

# %%
def changing_names_of_index(table_index, right_index):
     energy_table.rename(
        index={table_index: right_index}, 
        inplace = True
     )

# %%
changing_attr_arr = [
    ['BOLIVIA (PLURIN. STATE OF)', 'BOLIVIA (PLURINATIONAL STATE OF)'],
    ['CÔTE D’IVOIRE', "CÔTE D'IVOIRE"],
    ["DEM. PEOPLE'S REP. KOREA", "DEMOCRATIC PEOPLE'S REPUBLIC OF KOREA"],
    ["DEM. REP. OF THE CONGO", 'DEMOCRATIC REPUBLIC OF THE CONGO'],
    ["LAO PEOPLE'S DEM. REP.", "LAO PEOPLE'S DEMOCRATIC REPUBLIC"],
    ['MICRONESIA (FED. STATES OF)', 'MICRONESIA (FEDERATED STATES OF)'],
    ['SAINT VINCENT & GRENADINES', 'SAINT VINCENT AND THE GRENADINES'],
    ['TÜRKIYE', 'TURKIYE'],
    ['UNITED REP. OF TANZANIA', 'UNITED REPUBLIC OF TANZANIA'],
    ['UNITED STATES OF AMERICA', 'UNITED STATES'],
    ['VENEZUELA (BOLIV. REP. OF)', 'VENEZUELA (BOLIVARIAN REPUBLIC OF)']
]

for item in changing_attr_arr:
    changing_names_of_index(item[0], item[1])
    
#population_table.loc[[changing_attr_arr[-1][1]], list(population_table.columns)]

# %%
#country_attr_table_2.to_csv('country_attr_table_2.csv')

# %%
energy_table
# Out:
#                           Primary energy production (petajoules), 2020
# Country
# AFGHANISTAN                                                         71
# ALBANIA                                                             63
# ALGERIA                                                          5,506
# AMERICAN SAMOA                                                       0
# ANDORRA                                                              1
# ...                                                                ...
# VIET NAM                                                         2,509
# WALLIS AND FUTUNA ISLANDS                                            0
# YEMEN                                                              164
# ZAMBIA                                                             405
# ZIMBABWE                                                           377
#
# [222 rows x 1 columns]

# %% [markdown]
# ### 2.3 Валовой внутренний продукт и валовой внутренний продукт на душу населения
# #### Gross domestic product and gross domestic product per capita

# %%
country_attr_table_2 = pd.read_csv('country_attr_table_2.csv', index_col='Country')
country_attr_table_2
# Out:
#                                    Country index   latitude   longitude  \
# Country
# AFGHANISTAN                                   AF  33.939110   67.709953
# ALBANIA                                       AL  41.153332   20.168331
# ALGERIA                                       DZ  28.033886    1.659626
# ANDORRA                                       AD  42.546245    1.601554
# ANGOLA                                        AO -11.202692   17.873887
# ...                                          ...        ...         ...
# VENEZUELA (BOLIVARIAN REPUBLIC OF)            VE   6.423750  -66.589730
# VIET NAM                                      VN  14.058324  108.277199
# YEMEN                                         YE  15.552727   48.516388
# ZAMBIA                                        ZM -13.133897   27.849332
# ZIMBABWE                                      ZW -19.015438   29.154857
#
#                                    Population mid-year estimates (millions), 2022  \
# Country
# ...

# %%
syb65__T13_table = pd.read_csv('reports/syb66__T13.csv', encoding='ISO-8859-1')
syb65__T13_table
# Out:
#                       T13  \
# 0     Region/Country/Area
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 6771                  716
# 6772                  716
# 6773                  716
# 6774                  716
# 6775                  716
#
#      Gross domestic product and gross domestic product per capita Unnamed: 2  \
# 0                                                   NaN                 Year
# 1                         Total, all countries or areas                 1995
# 2                         Total, all countries or areas                 2005
# 3                         Total, all countries or areas                 2010
# 4                         Total, all countries or areas                 2015
# ...                                                 ...                  ...
# 6771                                           Zimbabwe                 2010
# ...

# %%
GDP_table = syb65__T13_table[
    (syb65__T13_table['Unnamed: 2'] == '2021') 
    #& 
    #(syb65__T23_table['Production, trade and supply of energy'] == 'Zimbabwe')
    &
    (
        (syb65__T13_table['Unnamed: 3'] == 'GDP in current prices (millions of US dollars)')
    )    
][30:].drop(
    ['T13', 'Unnamed: 2', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 3'], axis = 1
).rename(
    columns={
        'Gross domestic product and gross domestic product per capita': 'Country', 
        'Unnamed: 4': 'GDP in current prices (millions of US dollars), 2021'
    }
)

GDP_table
# Out:
#           Country GDP in current prices (millions of US dollars), 2021
# 847   Afghanistan                                             14,939
# 875       Albania                                             18,260
# 903       Algeria                                            163,473
# 931       Andorra                                              3,325
# 959        Angola                                             70,533
# ...           ...                                                ...
# 6642     Viet Nam                                            366,138
# 6670        Yemen                                              9,947
# 6698       Zambia                                             21,313
# 6726     Zanzibar                                              2,080
# 6754     Zimbabwe                                             24,118
#
# [212 rows x 2 columns]

# %%
GDP_table['Country'] = [x.upper() for x in GDP_table['Country']]

# %%
GDP_table.set_index(
    'Country', inplace = True
)
GDP_table
# Out:
#             GDP in current prices (millions of US dollars), 2021
# Country
# AFGHANISTAN                                             14,939
# ALBANIA                                                 18,260
# ALGERIA                                                163,473
# ANDORRA                                                  3,325
# ANGOLA                                                  70,533
# ...                                                        ...
# VIET NAM                                               366,138
# YEMEN                                                    9,947
# ZAMBIA                                                  21,313
# ZANZIBAR                                                 2,080
# ZIMBABWE                                                24,118
#
# [212 rows x 1 columns]

# %%
def changing_names_of_index(table_index, right_index):
     GDP_table.rename(
        index={table_index: right_index}, 
        inplace = True
     )

# %%
changing_attr_arr = [
    ['BOLIVIA (PLURIN. STATE OF)', 'BOLIVIA (PLURINATIONAL STATE OF)'],
    ['CÔTE D’IVOIRE', "CÔTE D'IVOIRE"],
    ["DEM. PEOPLE'S REP. KOREA", "DEMOCRATIC PEOPLE'S REPUBLIC OF KOREA"],
    ["DEM. REP. OF THE CONGO", 'DEMOCRATIC REPUBLIC OF THE CONGO'],
    ["LAO PEOPLE'S DEM. REP.", "LAO PEOPLE'S DEMOCRATIC REPUBLIC"],
    ['MICRONESIA (FED. STATES OF)', 'MICRONESIA (FEDERATED STATES OF)'],
    ['SAINT VINCENT & GRENADINES', 'SAINT VINCENT AND THE GRENADINES'],
    ['TÜRKIYE', 'TURKIYE'],
    ['UNITED REP. OF TANZANIA', 'UNITED REPUBLIC OF TANZANIA'],
    ['UNITED STATES OF AMERICA', 'UNITED STATES'],
    ['VENEZUELA (BOLIV. REP. OF)', 'VENEZUELA (BOLIVARIAN REPUBLIC OF)']
]

for item in changing_attr_arr:
    changing_names_of_index(item[0], item[1])
    
#population_table.loc[[changing_attr_arr[-1][1]], list(population_table.columns)]

# %%
GDP_table[10:50]
# Out:
#                                  GDP in current prices (millions of US dollars), 2021
# Country
# AUSTRALIA                                                                 1,734,532
# AUSTRIA                                                                     480,368
# AZERBAIJAN                                                                   54,622
# BAHAMAS                                                                      11,209
# BAHRAIN                                                                      38,869
# BANGLADESH                                                                  414,907
# BARBADOS                                                                      4,844
# BELARUS                                                                      68,206
# BELGIUM                                                                     594,104
# BELIZE                                                                        2,492
# ...

# %%
country_attr_table_3 = pd.merge(
    country_attr_table_2, 
    GDP_table, 
    how='outer', 
    left_index=True, 
    right_index=True
)#.dropna(
    #subset=['latitude']
#)#.to_csv(
    #'country_attr_table.csv'
#) 

country_attr_table_3
# Out:
#             Country index   latitude   longitude  \
# Country
# AFGHANISTAN            AF  33.939110   67.709953
# ALBANIA                AL  41.153332   20.168331
# ALGERIA                DZ  28.033886    1.659626
# ANDORRA                AD  42.546245    1.601554
# ANGOLA                 AO -11.202692   17.873887
# ...                   ...        ...         ...
# VIET NAM               VN  14.058324  108.277199
# YEMEN                  YE  15.552727   48.516388
# ZAMBIA                 ZM -13.133897   27.849332
# ZANZIBAR              NaN        NaN         NaN
# ZIMBABWE               ZW -19.015438   29.154857
#
#             Population mid-year estimates (millions), 2022  \
# Country
# AFGHANISTAN                                          41.13
# ALBANIA                                               2.84
# ALGERIA                                              44.90
# ANDORRA                                               0.08
# ...

# %%
#country_attr_table_3[[isinstance(x, float) for x in country_attr_table_3[column_name]]]

# %%
#country_attr_table_3[column_name][112]
#not(isinstance(country_attr_table_3[column_name][112], float))

# %%
#country_attr_table_3[isinstance(country_attr_table_3[column_name], float)]

# %%
column_name = 'GDP in current prices (millions of US dollars), 2020'

#country_attr_table_3[column_name] = str(country_attr_table_3[column_name]) 

#change_type_val(column_name)
country_attr_table_3[
        column_name
    ] = [
        #x.replace(',', '') for x in country_attr_table_3[column_name] if not(isinstance(x, float))
        x if isinstance(x, float) else x.replace(',', '') for x in country_attr_table_3[column_name] 
    ]
    

country_attr_table_3[column_name] = pd.to_numeric(country_attr_table_3[column_name])

# %%
type(country_attr_table_3[column_name][2])
#country_attr_table_3[column_name][2]
# Out:
# numpy.int64

# %%
country_attr_table_3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-1265857ffbe8> in <module>
# ----> 1 country_attr_table_3
#
# NameError: name 'country_attr_table_3' is not defined

# %%
country_attr_table_3[country_attr_table_3['Country'] == 'TURKEY']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Country, Country index, latitude, longitude, Population mid-year estimates (millions), 2022, Primary energy production (petajoules), 2019, GDP in current prices (millions of US dollars), 2020]
# Index: []

# %%
country_attr_table_3[country_attr_table_3['Country'] == 'TURKIYE']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Country, Country index, latitude, longitude, Population mid-year estimates (millions), 2022, Primary energy production (petajoules), 2019, GDP in current prices (millions of US dollars), 2020]
# Index: []

# %%
country_attr_table_3[country_attr_table_3['Country'] == 'TÜRKIYE']
# Out:
#      Unnamed: 0  Country Country index   latitude  longitude  \
# 176         176  TÜRKIYE            TR  38.963745  35.243322
#
#      Population mid-year estimates (millions), 2022  \
# 176                                           85.34
#
#      Primary energy production (petajoules), 2019  \
# 176                                        1891.0
#
#      GDP in current prices (millions of US dollars), 2020
# 176                                             720098

# %%
country_attr_table_3['Country'].replace({'TURKIYE': 'TÜRKIYE'}, inplace = True)

# %%
country_attr_table_3.to_csv('country_attr_table_3.csv')

# %% [markdown]
# ## 3. Добавление параметров узлов в сеть

# %%
country_attr_table_3 = pd.read_csv('country_attr_table_3.csv')
country_attr_table_3
# Out:
#      Unnamed: 0  Unnamed: 0.1                             Country  \
# 0             0             0                         AFGHANISTAN
# 1             1             1                             ALBANIA
# 2             2             2                             ALGERIA
# 3             3             3                             ANDORRA
# 4             4             4                              ANGOLA
# ..          ...           ...                                 ...
# 188         188           188  VENEZUELA (BOLIVARIAN REPUBLIC OF)
# 189         189           189                            VIET NAM
# 190         190           190                               YEMEN
# 191         191           191                              ZAMBIA
# 192         192           192                            ZIMBABWE
#
#     Country index   latitude   longitude  \
# 0              AF  33.939110   67.709953
# 1              AL  41.153332   20.168331
# 2              DZ  28.033886    1.659626
# ...

# %%
nodes_array_un = []

for index in range (0, len(country_attr_table_3)):
    nodes_array_un.append(
        (
            country_attr_table_3['Country'][index], 
         {
             'latitude': country_attr_table['latitude'][index],
             'longitude': country_attr_table['longitude'][index],
             'Population': country_attr_table_3['Population mid-year estimates (millions), 2022'][index],
             'Energy': country_attr_table_3['Primary energy production (petajoules), 2019'][index],
             'GDP': country_attr_table_3['GDP in current prices (millions of US dollars), 2020'][index],
             'CI': country_attr_table_3['Country index'][index],
         }
        ) 
    )

# %%
G_3 = nx.Graph()
G_3.add_nodes_from(nodes_array_un)

# %%
G2 = nx.read_gexf('UN_UKRAINE--POLITICAL_CONDITIONS_.gexf')

# %%
len(G2)
# Out:
# 193

# %%
R = nx.compose(G2, G_3)

# %%
R.nodes(data=True)
# Out:
# NodeDataView({'AFGHANISTAN': {'label': 'AFGHANISTAN', 'latitude': 33.93911, 'longitude': 67.709953, 'Population': 41.13, 'Energy': 82.0, 'GDP': 19793, 'CI': 'AF'}, 'ALBANIA': {'label': 'ALBANIA', 'latitude': 41.153332, 'longitude': 20.168331, 'Population': 2.84, 'Energy': 71.0, 'GDP': 14910, 'CI': 'AL'}, 'ALGERIA': {'label': 'ALGERIA', 'latitude': 28.033886, 'longitude': 1.6596259999999998, 'Population': 44.9, 'Energy': 5954.0, 'GDP': 147689, 'CI': 'DZ'}, 'ANDORRA': {'label': 'ANDORRA', 'latitude': 42.546245, 'longitude': 1.6015540000000001, 'Population': 0.08, 'Energy': 1.0, 'GDP': 2864, 'CI': 'AD'}, 'ANGOLA': {'label': 'ANGOLA', 'latitude': -11.202691999999999, 'longitude': 17.873887, 'Population': 35.59, 'Energy': 3639.0, 'GDP': 62307, 'CI': 'AO'}, 'ANTIGUA AND BARBUDA': {'label': 'ANTIGUA AND BARBUDA', 'latitude': 17.060816, 'longitude': -61.79642800000001, 'Population': 0.09, 'Energy': 0.0, 'GDP': 1370, 'CI': 'AG'}, 'ARGENTINA': {'label': 'ARGENTINA', 'latitude': -38.416097, 'lo
# ...

# %%
nx.write_gexf(R, 'UN_UKRAINE--POLITICAL_CONDITIONS_attr_4.gexf')

# %%
len(R)
# Out:
# 193

# %%
G_3.nodes(Data=True)
#G2.nodes()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a9b55de84033> in <module>
# ----> 1 G_3.nodes(Data=True)
#       2 #G2.nodes()
#
# NameError: name 'G_3' is not defined

# %%
set(G2.nodes()).difference(G_3.nodes())
# Out:
# set()
