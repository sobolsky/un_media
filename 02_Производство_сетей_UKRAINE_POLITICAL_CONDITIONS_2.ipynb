# %% [markdown]
# # 02 Производство сетей
# ### UKRAINE_POLITICAL_CONDITIONS--REPORTS
# Производство сетей на основе манипуляции с общей таблицей

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from matplotlib.pyplot import figure

# %% [markdown]
# ## 1. Читаем общую таблицу по голосованиям с диска

# %%
votes_table_com = pd.read_csv('votes_table.csv')
votes_table_com
# Out:
#           Data     Resolution  \
# 0   2022-11-14  A/RES/ES-11/5
# 1   2022-10-12  A/RES/ES-11/4
# 2   2022-04-07  A/RES/ES-11/3
# 3   2022-03-24  A/RES/ES-11/2
# 4   2022-03-02  A/RES/ES-11/1
# 5   2022-11-30    A/RES/77/22
# 6   2022-11-30    A/RES/77/23
# 7   2022-11-30    A/RES/77/25
# 8   2022-11-30    A/RES/77/24
# 9   2022-12-15   A/RES/77/228
# 10  2022-12-15   A/RES/77/229
# 11  2022-12-15   A/RES/77/230
# 12  2023-02-23  A/RES/ES-11/6
#
#                                                 Title  \
# 0   Furtherance of remedy and reparation for aggre...
# 1   Territorial integrity of Ukraine : defending t...
# 2   Suspension of the rights of membership of the ...
# 3   Humanitarian consequences of the aggression ag...
# 4   Aggression against Ukraine : resolution / adop...
# 5   Committee on the Exercise of the Inalienable R...
# 6   Division for Palestinian Rights of the Secreta...
# 7   Peaceful settlement of the question of Palesti...
# 8   Special information programme on the question ...
# 9   Situation of human rights in the Islamic Repub...
# 10  Situation of human rights in the temporarily o...
# 11  Situation of human rights in the Syrian Arab R...
# 12  Principles of the Charter of the United Nation...
#
#                                              Uri  \
# 0   https://digitallibrary.un.org/record/3994052
# 1   https://digitallibrary.un.org/record/3990400
# 2   https://digitallibrary.un.org/record/3967778
# 3   https://digitallibrary.un.org/record/3965954
# 4   https://digitallibrary.un.org/record/3959039
# 5   https://digitallibrary.un.org/record/3996096
# 6   https://digitallibrary.un.org/record/3996095
# 7   https://digitallibrary.un.org/record/3996093
# 8   https://digitallibrary.un.org/record/3996092
# 9   https://digitallibrary.un.org/record/3997720
# 10  https://digitallibrary.un.org/record/3997713
# 11  https://digitallibrary.un.org/record/3997710
# 12  https://digitallibrary.un.org/record/4003921
#
#                             Tags                          Topic
# 0   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 1   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 2   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 3   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 4   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 5   ['Palestine, Israel', 'war']             PALESTINE QUESTION
# 6   ['Palestine, Israel', 'war']             PALESTINE QUESTION
# 7   ['Palestine, Israel', 'war']             PALESTINE QUESTION
# 8   ['Palestine, Israel', 'war']             PALESTINE QUESTION
# 9                       ['Iran']          HUMAN RIGHTS--REPORTS
# 10         ['Ukraine', 'Crimea']          HUMAN RIGHTS--REPORTS
# 11                    ['Syrian']          HUMAN RIGHTS--REPORTS
# 12  ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS

# %% [markdown]
# ## 2. Data processing

# %%
#votes_table_com['Tags'] = list(votes_table_com['Tags'].apply(lambda x: x[1:-1]))
#votes_table_com

# %%
#votes_table_com.to_csv('votes_table.csv', index=False) 
#votes_table_com.drop([9], inplace=True)

# %%
#topic = 'PALESTINE QUESTION'
#topic = 'HUMAN RIGHTS--REPORTS'
topic = 'UKRAINE--POLITICAL CONDITIONS'
votes_table_com = votes_table_com[votes_table_com['Topic'] == topic]

# %%
votes_table_com
# Out:
#           Data     Resolution  \
# 0   2022-11-14  A/RES/ES-11/5
# 1   2022-10-12  A/RES/ES-11/4
# 2   2022-04-07  A/RES/ES-11/3
# 3   2022-03-24  A/RES/ES-11/2
# 4   2022-03-02  A/RES/ES-11/1
# 12  2023-02-23  A/RES/ES-11/6
#
#                                                 Title  \
# 0   Furtherance of remedy and reparation for aggre...
# 1   Territorial integrity of Ukraine : defending t...
# 2   Suspension of the rights of membership of the ...
# 3   Humanitarian consequences of the aggression ag...
# 4   Aggression against Ukraine : resolution / adop...
# 12  Principles of the Charter of the United Nation...
#
#                                              Uri  \
# 0   https://digitallibrary.un.org/record/3994052
# 1   https://digitallibrary.un.org/record/3990400
# 2   https://digitallibrary.un.org/record/3967778
# 3   https://digitallibrary.un.org/record/3965954
# 4   https://digitallibrary.un.org/record/3959039
# 12  https://digitallibrary.un.org/record/4003921
#
#                             Tags                          Topic
# 0   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 1   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 2   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 3   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 4   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 12  ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS

# %%
votes_table_com = votes_table_com.sort_values(
    by=['Data']
)
votes_table_com
# Out:
#           Data     Resolution  \
# 4   2022-03-02  A/RES/ES-11/1
# 3   2022-03-24  A/RES/ES-11/2
# 2   2022-04-07  A/RES/ES-11/3
# 1   2022-10-12  A/RES/ES-11/4
# 0   2022-11-14  A/RES/ES-11/5
# 12  2023-02-23  A/RES/ES-11/6
#
#                                                 Title  \
# 4   Aggression against Ukraine : resolution / adop...
# 3   Humanitarian consequences of the aggression ag...
# 2   Suspension of the rights of membership of the ...
# 1   Territorial integrity of Ukraine : defending t...
# 0   Furtherance of remedy and reparation for aggre...
# 12  Principles of the Charter of the United Nation...
#
#                                              Uri  \
# 4   https://digitallibrary.un.org/record/3959039
# 3   https://digitallibrary.un.org/record/3965954
# 2   https://digitallibrary.un.org/record/3967778
# 1   https://digitallibrary.un.org/record/3990400
# 0   https://digitallibrary.un.org/record/3994052
# 12  https://digitallibrary.un.org/record/4003921
#
#                             Tags                          Topic
# 4   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 3   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 2   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 1   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 0   ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS
# 12  ['russia', 'ukraine', 'war']  UKRAINE--POLITICAL CONDITIONS

# %% [markdown]
# ## 3. Net making

# %% [markdown]
# ###  3.1 Создание сводной таблицамы голосований

# %%
vote_array = [] # массив из таблиц голосований, полученных из файлов

votes_table_com['Resolution'].apply(
    lambda x: vote_array.append(
        pd.read_csv('resolution_vote/' + x.replace('/', '_') + '.csv', index_col = 'Country')
    )
)
# Out:
# 4     None
# 3     None
# 2     None
# 1     None
# 0     None
# 12    None
# Name: Resolution, dtype: object

# %%
len(vote_array)
# Out:
# 6

# %%
11n1

# %%
vote_array[0]
# Out:
#                                     A/RES/ES-11/1
# Country
# AFGHANISTAN                                   1.0
# ALBANIA                                       1.0
# ALGERIA                                       0.0
# ANDORRA                                       1.0
# ANGOLA                                        0.0
# ...                                           ...
# VENEZUELA (BOLIVARIAN REPUBLIC OF)            NaN
# VIET NAM                                      0.0
# YEMEN                                         1.0
# ZAMBIA                                        1.0
# ZIMBABWE                                      0.0
#
# [193 rows x 1 columns]

# %%
# Merge table

common_table = vote_array[0]

for index in range(1, len(vote_array)):
    common_table = pd.merge(common_table, vote_array[index], how='outer', left_index=True, right_index=True)

# %%
common_table
# Out:
#                                     A/RES/ES-11/1  A/RES/ES-11/2  \
# Country
# AFGHANISTAN                                   1.0            1.0
# ALBANIA                                       1.0            1.0
# ALGERIA                                       0.0            0.0
# ANDORRA                                       1.0            1.0
# ANGOLA                                        0.0            0.0
# ...                                           ...            ...
# VENEZUELA (BOLIVARIAN REPUBLIC OF)            NaN            NaN
# VIET NAM                                      0.0            0.0
# YEMEN                                         1.0            1.0
# ZAMBIA                                        1.0            1.0
# ZIMBABWE                                      0.0            0.0
#
#                                     A/RES/ES-11/3  A/RES/ES-11/4  \
# Country
# AFGHANISTAN                                   NaN            1.0
# ALBANIA                                       1.0            1.0
# ALGERIA                                      -1.0            0.0
# ANDORRA                                       1.0            1.0
# ANGOLA                                        0.0            1.0
# ...                                           ...            ...
# VENEZUELA (BOLIVARIAN REPUBLIC OF)            NaN            NaN
# VIET NAM                                     -1.0            0.0
# YEMEN                                         0.0            1.0
# ZAMBIA                                        NaN            1.0
# ZIMBABWE                                     -1.0            0.0
#
#                                     A/RES/ES-11/5  A/RES/ES-11/6
# Country
# AFGHANISTAN                                   1.0            1.0
# ALBANIA                                       1.0            1.0
# ALGERIA                                       0.0            0.0
# ANDORRA                                       1.0            1.0
# ANGOLA                                        0.0            0.0
# ...                                           ...            ...
# VENEZUELA (BOLIVARIAN REPUBLIC OF)            NaN            NaN
# VIET NAM                                      0.0            0.0
# YEMEN                                         0.0            1.0
# ZAMBIA                                        1.0            1.0
# ZIMBABWE                                     -1.0            0.0
#
# [196 rows x 6 columns]

# %% [markdown]
# ####  Убираем строчки со всеми NaN

# %%
#common_table.dropna(how='all', inplace = True, axis=0)

# %%
#common_table.dropna(inplace = True)

# %%
common_table
# Out:
#                                     A/RES/ES-11/5  A/RES/ES-11/4  \
# Country
# AFGHANISTAN                                   1.0            1.0
# ALBANIA                                       1.0            1.0
# ALGERIA                                       0.0            0.0
# ANDORRA                                       1.0            1.0
# ANGOLA                                        0.0            1.0
# ...                                           ...            ...
# VENEZUELA (BOLIVARIAN REPUBLIC OF)            NaN            NaN
# VIET NAM                                      0.0            0.0
# YEMEN                                         0.0            1.0
# ZAMBIA                                        1.0            1.0
# ZIMBABWE                                     -1.0            0.0
#
#                                     A/RES/ES-11/3  A/RES/ES-11/2  \
# Country
# AFGHANISTAN                                   NaN            1.0
# ALBANIA                                       1.0            1.0
# ALGERIA                                      -1.0            0.0
# ANDORRA                                       1.0            1.0
# ANGOLA                                        0.0            0.0
# ...                                           ...            ...
# VENEZUELA (BOLIVARIAN REPUBLIC OF)            NaN            NaN
# VIET NAM                                     -1.0            0.0
# YEMEN                                         0.0            1.0
# ZAMBIA                                        NaN            1.0
# ZIMBABWE                                     -1.0            0.0
#
#                                     A/RES/ES-11/1
# Country
# AFGHANISTAN                                   1.0
# ALBANIA                                       1.0
# ALGERIA                                       0.0
# ANDORRA                                       1.0
# ANGOLA                                        0.0
# ...                                           ...
# VENEZUELA (BOLIVARIAN REPUBLIC OF)            NaN
# VIET NAM                                      0.0
# YEMEN                                         1.0
# ZAMBIA                                        1.0
# ZIMBABWE                                      0.0
#
# [196 rows x 5 columns]

# %%
# назодим лигнюю страну
set(common_table.index).difference(vote_array[0].index)
# Out:
# {"COTE D'IVOIRE", 'TURKIYE', 'TÜRKIYE'}

# %%
len(common_table.index)
# Out:
# 196

# %%
#if 'UKRAINE' in common_table.index: print('True')

# %% [markdown]
# ### 3.2 Убираем разное написание Турции и "CÔTE D'IVOIRE"

# %%
common_table.loc[['TURKEY']]
# Out:
#          A/RES/ES-11/1  A/RES/ES-11/2  A/RES/ES-11/3  A/RES/ES-11/4  \
# Country
# TURKEY             1.0            1.0            1.0            NaN
#
#          A/RES/ES-11/5  A/RES/ES-11/6
# Country
# TURKEY             NaN            NaN

# %%
common_table.loc[['TURKIYE']]
# Out:
#          A/RES/ES-11/1  A/RES/ES-11/2  A/RES/ES-11/3  A/RES/ES-11/4  \
# Country
# TURKIYE            NaN            NaN            NaN            NaN
#
#          A/RES/ES-11/5  A/RES/ES-11/6
# Country
# TURKIYE            1.0            1.0

# %%
common_table[common_table.index == 'TÜRKIYE']
# Out:
#          A/RES/ES-11/1  A/RES/ES-11/2  A/RES/ES-11/3  A/RES/ES-11/4  \
# Country
# TÜRKIYE            NaN            NaN            NaN            1.0
#
#          A/RES/ES-11/5  A/RES/ES-11/6
# Country
# TÜRKIYE            NaN            NaN

# %%
common_table[common_table.index == "CÔTE D'IVOIRE"]
# Out:
#                A/RES/ES-11/1  A/RES/ES-11/2  A/RES/ES-11/3  A/RES/ES-11/4  \
# Country
# CÔTE D'IVOIRE            1.0            1.0            1.0            1.0
#
#                A/RES/ES-11/5  A/RES/ES-11/6
# Country
# CÔTE D'IVOIRE            NaN            NaN

# %%
common_table[common_table.index == "COTE D'IVOIRE"]
# Out:
#                A/RES/ES-11/1  A/RES/ES-11/2  A/RES/ES-11/3  A/RES/ES-11/4  \
# Country
# COTE D'IVOIRE            NaN            NaN            NaN            NaN
#
#                A/RES/ES-11/5  A/RES/ES-11/6
# Country
# COTE D'IVOIRE            1.0            1.0

# %%
#list(common_table[(common_table.index == 'TURKEY') + (common_table.index == 'TURKIYE') + (common_table.index == 'TÜRKIYE')].sum())

# %%
common_table.loc[["TURKEY", "TURKIYE", 'TÜRKIYE'], list(common_table.columns)]
# Out:
#          A/RES/ES-11/1  A/RES/ES-11/2  A/RES/ES-11/3  A/RES/ES-11/4  \
# Country
# TURKEY             1.0            1.0            1.0            NaN
# TURKIYE            NaN            NaN            NaN            NaN
# TÜRKIYE            NaN            NaN            NaN            1.0
#
#          A/RES/ES-11/5  A/RES/ES-11/6
# Country
# TURKEY             NaN            NaN
# TURKIYE            1.0            1.0
# TÜRKIYE            NaN            NaN

# %%
common_table.loc['TÜRKIYE'] = common_table.loc[["TURKEY", "TURKIYE", 'TÜRKIYE'], list(common_table.columns)].sum()
common_table.drop(["TURKEY", 'TURKIYE'], inplace = True)

# %%
common_table[common_table.index == 'TÜRKIYE']
# Out:
#          A/RES/ES-11/1  A/RES/ES-11/2  A/RES/ES-11/3  A/RES/ES-11/4  \
# Country
# TÜRKIYE            1.0            1.0            1.0            1.0
#
#          A/RES/ES-11/5  A/RES/ES-11/6
# Country
# TÜRKIYE            1.0            1.0

# %%
common_table.loc["CÔTE D'IVOIRE"] = common_table.loc[["CÔTE D'IVOIRE", "COTE D'IVOIRE"], list(common_table.columns)].sum()
common_table.drop(["COTE D'IVOIRE"], inplace = True)

common_table[common_table.index == "CÔTE D'IVOIRE"]
#common_table[["CÔTE D'IVOIRE"]]
# Out:
#                A/RES/ES-11/1  A/RES/ES-11/2  A/RES/ES-11/3  A/RES/ES-11/4  \
# Country
# CÔTE D'IVOIRE            1.0            1.0            1.0            1.0
#
#                A/RES/ES-11/5  A/RES/ES-11/6
# Country
# CÔTE D'IVOIRE            1.0            1.0

# %%
common_table.to_csv(topic + '_vote_table_2023.csv', index=True)

# %% [markdown]
# ###  3.2 Вычисление показателя солидарности для каждого голосования

# %%
# принимает таблицу с рещультатами голосования common_table
# возвращает два массива c парной узлов (ребром)

def get_edges(table):
    nodes_1 = []
    nodes_2 = []
    count_index = len(common_table.index)
    
    for index_first in range(0, count_index-1):
        for index_second in range(index_first+1, count_index):

            nodes_1.append(table.index[index_first])
            nodes_2.append(table.index[index_second])
        
    return [nodes_1, nodes_2]

# %%
# принимает таблицу с результатами голосования из common_table и название расчетного столбца голосования 
# возвращает массив оценки солидарности шголосования solid_val

def get_solid_val(table, item):
    solid_val = []
    count_index = len(table.index)
    
    for index_first in range(0, count_index-1):
        for index_second in range(index_first+1, count_index):
            
            # сравнение индексов голосования
            if (pd.isnull(table.iloc[index_first][item]) or pd.isnull(table.iloc[index_second][item])): 
                solid_val.append(np.nan) 
            else: 
                # Это значит, что если оба воздержались, то 0 == 0 это True
                solid_val.append(table.iloc[index_first][item] == table.iloc[index_second][item])
                # Нужно ли давать 1 если 1 == 1, -1 если -1 == -1... как быть с 0?
            
    return solid_val

# %%
#
# ЗАГРУЗНЫЙ ПРЦЕСС !!!!!
#
# создаем таблицу ребер сети

net_table = pd.DataFrame()

# создаем все ребра сети
nodes_arr = get_edges(common_table)
net_table['Nodes_1'] = nodes_arr[0]
net_table['Nodes_2'] = nodes_arr[1]

# заполняем результаты голосований
for item in common_table.columns: 
    net_table[item] = get_solid_val(common_table, item)

net_table
# Out:
#            Nodes_1              Nodes_2 A/RES/ES-11/1 A/RES/ES-11/2  \
# 0      AFGHANISTAN              ALBANIA          True          True
# 1      AFGHANISTAN              ALGERIA         False         False
# 2      AFGHANISTAN              ANDORRA          True          True
# 3      AFGHANISTAN               ANGOLA         False         False
# 4      AFGHANISTAN  ANTIGUA AND BARBUDA          True          True
# ...            ...                  ...           ...           ...
# 18523     VIET NAM               ZAMBIA         False         False
# 18524     VIET NAM             ZIMBABWE          True          True
# 18525        YEMEN               ZAMBIA          True          True
# 18526        YEMEN             ZIMBABWE         False         False
# 18527       ZAMBIA             ZIMBABWE         False         False
#
#       A/RES/ES-11/3 A/RES/ES-11/4 A/RES/ES-11/5 A/RES/ES-11/6
# 0               NaN          True          True          True
# 1               NaN         False         False         False
# 2               NaN          True          True          True
# 3               NaN          True         False         False
# 4               NaN          True         False          True
# ...             ...           ...           ...           ...
# 18523           NaN         False         False         False
# 18524          True          True         False          True
# 18525           NaN          True         False          True
# 18526         False         False         False         False
# 18527           NaN         False         False         False
#
# [18528 rows x 8 columns]

# %%
#net_table[net_table['Nodes_1'] == 'RUSSIAN FEDERATION']
#net_table[((net_table['Nodes_1'] == 'THAILAND') & (net_table['Nodes_2'] == 'ANTIGUA AND BARBUDA'))]

#RUSSIAN FEDERATION

# %% [markdown]
# ### 3.3 Вычисление коэффициента солидарности (веса) для каждого из ребер
#
# `Solid_val` коэффициент солидарности (вес ребер)

# %%
#net_table_weight = net_table.replace({True: 1, False: -1})
net_table_weight = net_table.replace({True: 1, False: 0})

#net_table_weight = net_table

net_table_weight['Solid_val'] = abs(net_table_weight[list(net_table_weight.columns)[2:]].sum(axis=1))
#net_table_weight['Solid_val'] = net_table_weight[list(net_table_weight.columns)[2:]].sum(axis=1)


net_table_weight.drop(list(net_table_weight.columns)[2:-1], inplace=True, axis=1)

#net_table_weight = net_table_weight[net_table_weight.Solid_val != 0]
# выбираем все значения больще n
net_table_weight = net_table_weight[net_table_weight.Solid_val >=1]

net_table_weight
# Out:
#            Nodes_1              Nodes_2  Solid_val
# 0      AFGHANISTAN              ALBANIA        5.0
# 2      AFGHANISTAN              ANDORRA        5.0
# 3      AFGHANISTAN               ANGOLA        1.0
# 4      AFGHANISTAN  ANTIGUA AND BARBUDA        4.0
# 5      AFGHANISTAN            ARGENTINA        5.0
# ...            ...                  ...        ...
# 18515      VANUATU                YEMEN        5.0
# 18516      VANUATU               ZAMBIA        5.0
# 18522     VIET NAM                YEMEN        1.0
# 18524     VIET NAM             ZIMBABWE        5.0
# 18525        YEMEN               ZAMBIA        4.0
#
# [13352 rows x 3 columns]

# %%
#net_table[net_table['Nodes_1'] == 'RUSSIAN FEDERATION']
#net_table_weight[((net_table_weight['Nodes_1'] == 'AFGHANISTAN') & (net_table_weight['Nodes_2'] == 'ANTIGUA AND BARBUDA'))]

# %% [markdown]
# ####  Немного статистики

# %%
set(net_table_weight['Solid_val'].isna())
# Out:
# {False}

# %%
len(net_table_weight)
# Out:
# 13352

# %%
#len(net_table_weight['Solid_val'][net_table_weight['Solid_val'] == 5])

# %%
len(net_table_weight['Solid_val'])
#len(net_table_weight['Solid_val'][net_table_weight['Solid_val'] == 0])
# Out:
# 13352

# %%
plt.hist(net_table_weight['Solid_val'], bins=18)
# Out:
# (array([1329.,    0.,    0., 1134.,    0.,    0.,    0., 1411.,    0.,
#            0., 3139.,    0.,    0.,    0., 3060.,    0.,    0., 3279.]),
#  array([1.        , 1.27777778, 1.55555556, 1.83333333, 2.11111111,
#         2.38888889, 2.66666667, 2.94444444, 3.22222222, 3.5       ,
#         3.77777778, 4.05555556, 4.33333333, 4.61111111, 4.88888889,
#         5.16666667, 5.44444444, 5.72222222, 6.        ]),
#  <BarContainer object of 18 artists>)

# %% [markdown]
# ### 3.3 Строим сеть

# %%
G = nx.Graph()
G.add_nodes_from(list(common_table.index))
net_table_weight.apply(lambda x: G.add_edge(x[0], x[1], weight= x[2]), axis=1)
# Out:
# 0        None
# 2        None
# 3        None
# 4        None
# 5        None
#          ...
# 18515    None
# 18516    None
# 18522    None
# 18524    None
# 18525    None
# Length: 13352, dtype: object

# %%
len(G.nodes())
# Out:
# 193

# %%
G.edges()
# Out:
# EdgeView([('AFGHANISTAN', 'ALBANIA'), ('AFGHANISTAN', 'ANDORRA'), ('AFGHANISTAN', 'ANGOLA'), ('AFGHANISTAN', 'ANTIGUA AND BARBUDA'), ('AFGHANISTAN', 'ARGENTINA'), ('AFGHANISTAN', 'AUSTRALIA'), ('AFGHANISTAN', 'AUSTRIA'), ('AFGHANISTAN', 'BAHAMAS'), ('AFGHANISTAN', 'BAHRAIN'), ('AFGHANISTAN', 'BANGLADESH'), ('AFGHANISTAN', 'BARBADOS'), ('AFGHANISTAN', 'BELGIUM'), ('AFGHANISTAN', 'BELIZE'), ('AFGHANISTAN', 'BENIN'), ('AFGHANISTAN', 'BHUTAN'), ('AFGHANISTAN', 'BOSNIA AND HERZEGOVINA'), ('AFGHANISTAN', 'BOTSWANA'), ('AFGHANISTAN', 'BRAZIL'), ('AFGHANISTAN', 'BRUNEI DARUSSALAM'), ('AFGHANISTAN', 'BULGARIA'), ('AFGHANISTAN', 'CABO VERDE'), ('AFGHANISTAN', 'CAMBODIA'), ('AFGHANISTAN', 'CANADA'), ('AFGHANISTAN', 'CHAD'), ('AFGHANISTAN', 'CHILE'), ('AFGHANISTAN', 'COLOMBIA'), ('AFGHANISTAN', 'COMOROS'), ('AFGHANISTAN', 'COSTA RICA'), ('AFGHANISTAN', 'CROATIA'), ('AFGHANISTAN', 'CYPRUS'), ('AFGHANISTAN', 'CZECHIA'), ('AFGHANISTAN', "CÔTE D'IVOIRE"), ('AFGHANISTAN', 'DEMOCRATIC REPUBLIC OF THE CONGO'), ('AFGHANISTAN', 'DENMARK'), ('AFGHANISTAN', 'DJIBOUTI'), ('AFGHANISTAN', 'DOMINICA'), ('AFGHANISTAN', 'DOMINICAN REPUBLIC'), ('AFGHANISTAN', 'ECUADOR'), ('AFGHANISTAN', 'EGYPT'), ('AFGHANISTAN', 'ESTONIA'), ('AFGHANISTAN', 'FIJI'), ('AFGHANISTAN', 'FINLAND'), ('AFGHANISTAN', 'FRANCE'), ('AFGHANISTAN', 'GABON'), ('AFGHANISTAN', 'GAMBIA'), ('AFGHANISTAN', 'GEORGIA'), ('AFGHANISTAN', 'GERMANY'), ('AFGHANISTAN', 'GHANA'), ('AFGHANISTAN', 'GREECE'), ('AFGHANISTAN', 'GRENADA'), ('AFGHANISTAN', 'GUATEMALA'), ('AFGHANISTAN', 'GUINEA-BISSAU'), ('AFGHANISTAN', 'GUYANA'), ('AFGHANISTAN', 'HAITI'), ('AFGHANISTAN', 'HONDURAS'), ('AFGHANISTAN', 'HUNGARY'), ('AFGHANISTAN', 'ICELAND'), ('AFGHANISTAN', 'INDONESIA'), ('AFGHANISTAN', 'IRAQ'), ('AFGHANISTAN', 'IRELAND'), ('AFGHANISTAN', 'ISRAEL'), ('AFGHANISTAN', 'ITALY'), ('AFGHANISTAN', 'JAMAICA'), ('AFGHANISTAN', 'JAPAN'), ('AFGHANISTAN', 'JORDAN'), ('AFGHANISTAN', 'KENYA'), ('AFGHANISTAN', 'KIRIBATI'), ('AFGHANISTAN', 'KUWAIT'), ('AFGHANISTAN', 'LATVIA'), ('AFGHANISTAN', 'LEBANON'), ('AFGHANISTAN', 'LESOTHO'), ('AFGHANISTAN', 'LIBERIA'), ('AFGHANISTAN', 'LIBYA'), ('AFGHANISTAN', 'LIECHTENSTEIN'), ('AFGHANISTAN', 'LITHUANIA'), ('AFGHANISTAN', 'LUXEMBOURG'), ('AFGHANISTAN', 'MADAGASCAR'), ('AFGHANISTAN', 'MALAWI'), ('AFGHANISTAN', 'MALAYSIA'), ('AFGHANISTAN', 'MALDIVES'), ('AFGHANISTAN', 'MALTA'), ('AFGHANISTAN', 'MARSHALL ISLANDS'), ('AFGHANISTAN', 'MAURITANIA'), ('AFGHANISTAN', 'MAURITIUS'), ('AFGHANISTAN', 'MEXICO'), ('AFGHANISTAN', 'MICRONESIA (FEDERATED STATES OF)'), ('AFGHANISTAN', 'MONACO'), ('AFGHANISTAN', 'MONTENEGRO'), ('AFGHANISTAN', 'MOROCCO'), ('AFGHANISTAN', 'MYANMAR'), ('AFGHANISTAN', 'NAURU'), ('AFGHANISTAN', 'NEPAL'), ('AFGHANISTAN', 'NETHERLANDS'), ('AFGHANISTAN', 'NEW ZEALAND'), ('AFGHANISTAN', 'NIGER'), ('AFGHANISTAN', 'NIGERIA'), ('AFGHANISTAN', 'NORTH MACEDONIA'), ('AFGHANISTAN', 'NORWAY'), ('AFGHANISTAN', 'OMAN'), ('AFGHANISTAN', 'PALAU'), ('AFGHANISTAN', 'PANAMA'), ('AFGHANISTAN', 'PAPUA NEW GUINEA'), ('AFGHANISTAN', 'PARAGUAY'), ('AFGHANISTAN', 'PERU'), ('AFGHANISTAN', 'PHILIPPINES'), ('AFGHANISTAN', 'POLAND'), ('AFGHANISTAN', 'PORTUGAL'), ('AFGHANISTAN', 'QATAR'), ('AFGHANISTAN', 'REPUBLIC OF KOREA'), ('AFGHANISTAN', 'REPUBLIC OF MOLDOVA'), ('AFGHANISTAN', 'ROMANIA'), ('AFGHANISTAN', 'RWANDA'), ('AFGHANISTAN', 'SAINT KITTS AND NEVIS'), ('AFGHANISTAN', 'SAINT LUCIA'), ('AFGHANISTAN', 'SAINT VINCENT AND THE GRENADINES'), ('AFGHANISTAN', 'SAMOA'), ('AFGHANISTAN', 'SAN MARINO'), ('AFGHANISTAN', 'SAO TOME AND PRINCIPE'), ('AFGHANISTAN', 'SAUDI ARABIA'), ('AFGHANISTAN', 'SENEGAL'), ('AFGHANISTAN', 'SERBIA'), ('AFGHANISTAN', 'SEYCHELLES'), ('AFGHANISTAN', 'SIERRA LEONE'), ('AFGHANISTAN', 'SINGAPORE'), ('AFGHANISTAN', 'SLOVAKIA'), ('AFGHANISTAN', 'SLOVENIA'), ('AFGHANISTAN', 'SOLOMON ISLANDS'), ('AFGHANISTAN', 'SOMALIA'), ('AFGHANISTAN', 'SOUTH SUDAN'), ('AFGHANISTAN', 'SPAIN'), ('AFGHANISTAN', 'SURINAME'), ('AFGHANISTAN', 'SWEDEN'), ('AFGHANISTAN', 'SWITZERLAND'), ('AFGHANISTAN', 'THAILAN ...

# %%
nx.is_connected(G)
# Out:
# False

# %%
figure(figsize=(20, 10))
nx.draw_networkx(G)

# %%
print(len(sorted(nx.connected_components(G))))
print(len(G.nodes()))
# Out:
# 1
# 183

# %%
print(round(nx.average_clustering(G), 2))
print(round(nx.transitivity(G), 2))
# Out:
# 0.99
# 1.0

# %%
#country_name = 'TURKIYE'
country_name = 'RUSSIAN FEDERATION'
#country_name = 'UNITED STATES'
#country_name = 'ISRAEL'
#UNITED STATES OF AMERICA

for index in range (0, len(list(nx.connected_components(G)))):
    print('')
    print(index)
    
    if country_name in list(nx.connected_components(G))[index]: print('True')
    else: print('False')
        
    print('')
    
    country_arr_test = list(nx.connected_components(G))[index]
    print(country_arr_test)
    print('______________')
# Out:
# 0
# False
#
# {'SPAIN', 'ROMANIA', 'LUXEMBOURG', 'LATVIA', 'CZECHIA', 'PALAU', 'SAMOA', 'AUSTRALIA', 'FRANCE', 'SWEDEN', 'TIMOR-LESTE', 'MALTA', 'COSTA RICA', 'LITHUANIA', 'GREECE', 'IRELAND', 'NEW ZEALAND', 'UNITED KINGDOM', 'SLOVENIA', 'LIBERIA', 'UNITED STATES', 'ITALY', 'SAN MARINO', 'URUGUAY', 'MONTENEGRO', 'BOSNIA AND HERZEGOVINA', 'NETHERLANDS', 'POLAND', 'CABO VERDE', 'ICELAND', 'FINLAND', 'ECUADOR', 'CROATIA', 'CYPRUS', 'LIECHTENSTEIN', 'MALAWI', 'TUVALU', 'REPUBLIC OF KOREA', 'UKRAINE', 'PORTUGAL', 'BULGARIA', 'BAHAMAS', 'NORWAY', 'SWITZERLAND', 'BARBADOS', 'REPUBLIC OF MOLDOVA', 'DENMARK', 'GERMANY', 'HUNGARY', 'JAPAN', 'ISRAEL', 'NORTH MACEDONIA', 'ALBANIA', 'ANDORRA', 'DOMINICAN REPUBLIC', 'AUSTRIA', 'ESTONIA', 'GUATEMALA', 'BELGIUM', 'MICRONESIA (FEDERATED STATES OF)', 'PANAMA', 'MONACO', 'KIRIBATI', 'MYANMAR', 'MARSHALL ISLANDS', 'ARGENTINA', 'SLOVAKIA', 'CANADA', 'SURINAME', 'CHILE'}
# ______________
#
# 1
# False
#
# {'LIBYA', 'KENYA', 'HAITI', 'SAINT KITTS AND NEVIS', 'UNITED REPUBLIC OF TANZANIA', 'GAMBIA', 'MONGOLIA', 'ZAMBIA', 'SAINT LUCIA', 'CAMEROON', 'MALAYSIA', 'GABON', 'ANGOLA', 'CONGO', 'GUINEA', 'MAURITANIA', 'MOZAMBIQUE', 'NAMIBIA', 'SINGAPORE', 'BURUNDI', 'GRENADA', 'RWANDA', 'TONGA', 'MAURITIUS', 'EGYPT', 'MADAGASCAR', 'TOGO', 'ESWATINI', 'SOUTH AFRICA', 'ANTIGUA AND BARBUDA', 'GHANA', 'NIGER', 'GUINEA-BISSAU', 'DJIBOUTI', 'NEPAL', 'TUNISIA', 'FIJI', 'UGANDA', 'UNITED ARAB EMIRATES', 'CENTRAL AFRICAN REPUBLIC', 'SOLOMON ISLANDS', 'SAINT VINCENT AND THE GRENADINES', "LAO PEOPLE'S DEMOCRATIC REPUBLIC", 'NIGERIA', 'TRINIDAD AND TOBAGO'}
# ______________
#
# 2
# False
#
# {'PAKISTAN', 'OMAN', 'SRI LANKA', 'INDONESIA', 'PHILIPPINES', 'ARMENIA', 'INDIA', 'TAJIKISTAN', 'BANGLADESH', 'KYRGYZSTAN', 'VIET NAM', 'BRUNEI DARUSSALAM', 'IRAQ'}
# ______________
#
# 3
# True
#
# {'RUSSIAN FEDERATION', 'CHINA', 'NICARAGUA', 'BELARUS', 'SYRIAN ARAB REPUBLIC', 'ZIMBABWE', "DEMOCRATIC PEOPLE'S REPUBLIC OF KOREA", 'ERITREA', 'IRAN (ISLAMIC REPUBLIC OF)', 'CUBA'}
# ______________
#
# 4
# False
#
# {'BHUTAN', 'BELIZE', 'CHAD', 'GUYANA'}
# ______________
#
# 5
# False
#
# {'MEXICO', 'COLOMBIA', 'EL SALVADOR', 'HONDURAS', 'PERU', 'BOTSWANA', 'YEMEN'}
# ______________
#
# 6
# False
#
# {"COTE D'IVOIRE", 'SENEGAL', 'THAILAND', 'JORDAN', 'BRAZIL'}
# ______________
#
# 7
# False
#
# {'KUWAIT', 'QATAR', 'PAPUA NEW GUINEA', 'JAMAICA'}
# ______________
#
# 8
# False
#
# {'KAZAKHSTAN', 'MALI'}
# ______________

# %% [markdown]
# ### 3.4  Профили голосования по теме:

# %%
# Ищем по первой букве
#common_table[common_table.index == 'AZERBAIJAN']
#common_table[common_table.index == 'TURKMENISTAN']
#common_table[common_table.index == 'VENEZUELA (BOLIVARIAN REPUBLIC OF)']
common_table[common_table.index == 'BURKINA FASO']
# Out:
#               A/RES/ES-11/5  A/RES/ES-11/4  A/RES/ES-11/3  A/RES/ES-11/2  \
# Country
# BURKINA FASO            NaN            NaN            NaN            NaN
#
#               A/RES/ES-11/1
# Country
# BURKINA FASO            NaN

# %%
common_table[common_table.index == 'CAMEROON']
# Out:
#           A/RES/77/228  A/RES/77/229  A/RES/77/230
# Country
# CAMEROON           0.0           0.0           0.0

# %%
common_table[common_table.index == 'NEPAL']
# Out:
#          A/RES/ES-11/5  A/RES/ES-11/4  A/RES/ES-11/3  A/RES/ES-11/2  \
# Country
# NEPAL              0.0            1.0            0.0            1.0
#
#          A/RES/ES-11/1
# Country
# NEPAL              1.0

# %%
common_table[common_table.index == 'RUSSIAN FEDERATION']
# Out:
#                     A/RES/ES-11/5  A/RES/ES-11/4  A/RES/ES-11/3  \
# Country
# RUSSIAN FEDERATION           -1.0           -1.0           -1.0
#
#                     A/RES/ES-11/2  A/RES/ES-11/1
# Country
# RUSSIAN FEDERATION           -1.0           -1.0

# %%
net_table[((net_table['Nodes_1'] == 'LESOTHO') & (net_table['Nodes_2'] == 'THAILAND'))]
# Out:
#        Nodes_1   Nodes_2 A/RES/ES-11/5 A/RES/ES-11/4 A/RES/ES-11/3  \
# 14042  LESOTHO  THAILAND          True          True          True
#
#       A/RES/ES-11/2 A/RES/ES-11/1
# 14042          True          True

# %%
net_table[net_table['Nodes_1'] == 'LESOTHO']
# Out:
#        Nodes_1                             Nodes_2 A/RES/ES-11/5  \
# 13968  LESOTHO                             LIBERIA         False
# 13969  LESOTHO                               LIBYA          True
# 13970  LESOTHO                       LIECHTENSTEIN         False
# 13971  LESOTHO                           LITHUANIA         False
# 13972  LESOTHO                          LUXEMBOURG         False
# ...        ...                                 ...           ...
# 14060  LESOTHO  VENEZUELA (BOLIVARIAN REPUBLIC OF)           NaN
# 14061  LESOTHO                            VIET NAM          True
# 14062  LESOTHO                               YEMEN          True
# 14063  LESOTHO                              ZAMBIA         False
# 14064  LESOTHO                            ZIMBABWE         False
#
#       A/RES/ES-11/4 A/RES/ES-11/3 A/RES/ES-11/2 A/RES/ES-11/1
# 13968         False         False          True          True
# 13969         False         False          True          True
# 13970         False         False          True          True
# 13971         False         False          True          True
# 13972         False         False          True          True
# ...             ...           ...           ...           ...
# 14060           NaN           NaN           NaN           NaN
# 14061          True         False         False         False
# 14062         False          True          True          True
# 14063         False           NaN          True          True
# 14064          True         False         False         False
#
# [97 rows x 7 columns]

# %% [markdown]
# ### 3.5 Строим сеть с разными весами

# %%
figure(figsize=(20, 10))

F = G.copy()
threshold = 6
F.remove_edges_from([(n1, n2) for n1, n2, w in F.edges(data="weight") if w < threshold])
#nx.draw(F)

pos = nx.spring_layout(F, seed=0)


for edge in F.edges(data='weight'):
    nx.draw_networkx_edges(F, pos, edgelist=[edge], width=edge[2] * edge[2])
       
nx.draw_networkx(F, pos)

# %%
print(len(sorted(nx.connected_components(F))))
print(len(F.nodes()))
# Out:
# 54
# 193

# %% [markdown]
# #### Связи -- единогласное голосования по всем резолюциям:

# %%
figure(figsize=(20, 10))

F = G.copy()
threshold = 5
F.remove_edges_from([(n1, n2) for n1, n2, w in F.edges(data="weight") if w < threshold])
#F.remove_nodes_from([(n1) for n1, n2, w in F.edges(data="weight") if w < threshold])
#nx.draw(F)
#net_table_weight.apply(lambda x: G.add_edge(x[0], x[1], weight= x[2]), axis=1)

# Для убирания отдельных нод
F5 = nx.Graph() 
F5.add_edges_from(F.edges(data = True))

pos = nx.spring_layout(F5, seed=0)

for edge in F5.edges(data='weight'):
    nx.draw_networkx_edges(F5, pos, edgelist=[edge], width=edge[2] * edge[2])
       
nx.draw_networkx(F5, pos)

# %%
print(len(sorted(nx.connected_components(F5))))
print(len(F5.nodes()))
# Out:
# 2
# 174

# %%
print(list(nx.connected_components(F))[1])
# Out:
# {'MALTA', 'SAMOA', 'CROATIA', 'CZECHIA', 'LIECHTENSTEIN', 'MICRONESIA (FEDERATED STATES OF)', 'NETHERLANDS', 'PORTUGAL', 'CHILE', 'ARGENTINA', 'FINLAND', 'PAPUA NEW GUINEA', 'SWEDEN', 'COLOMBIA', 'ROMANIA', 'URUGUAY', 'PHILIPPINES', 'BELGIUM', 'NEW ZEALAND', 'NAURU', 'CYPRUS', 'BULGARIA', 'SAN MARINO', 'PANAMA', 'PERU', 'SWITZERLAND', 'MALAWI', 'LIBERIA', 'UNITED STATES', 'GUATEMALA', 'COSTA RICA', 'MONACO', 'SEYCHELLES', 'ECUADOR', 'ESTONIA', 'PALAU', 'LITHUANIA', 'MONTENEGRO', 'AUSTRALIA', 'MARSHALL ISLANDS', 'ICELAND', 'DENMARK', 'FIJI', 'GERMANY', 'HUNGARY', 'GEORGIA', 'KIRIBATI', 'MYANMAR', 'TUVALU', 'ITALY', 'POLAND', 'UNITED KINGDOM', 'CHAD', 'NORWAY', 'UKRAINE', 'SLOVENIA', 'LATVIA', 'REPUBLIC OF MOLDOVA', 'AUSTRIA', 'ANDORRA', 'IRELAND', 'GREECE', 'DOMINICAN REPUBLIC', 'CANADA', 'NORTH MACEDONIA', 'JAPAN', 'PARAGUAY', 'FRANCE', 'LUXEMBOURG', 'ALBANIA', 'REPUBLIC OF KOREA', 'SLOVAKIA', 'TURKIYE', 'BOSNIA AND HERZEGOVINA', 'SPAIN'}

# %%
country_name = 'IRAN (ISLAMIC REPUBLIC OF)'
country_name = 'HUNGARY'

for index in range (0, len(list(nx.connected_components(F5)))):
    print('')
    print(index)
    
    if country_name in list(nx.connected_components(F5))[index]: print('True')
    else: print('False')
        
    print('')
    
    country_arr_test = list(nx.connected_components(F5))[index]
    print(country_arr_test)
    print('______________')
# Out:
# 0
# True
#
# {'SPAIN', 'ROMANIA', 'COLOMBIA', 'LUXEMBOURG', 'TÜRKIYE', 'LATVIA', 'PAPUA NEW GUINEA', 'CZECHIA', 'PALAU', 'SAMOA', 'AUSTRALIA', 'FRANCE', 'SWEDEN', 'NAURU', 'MALTA', 'COSTA RICA', 'LITHUANIA', 'GREECE', 'IRELAND', 'NEW ZEALAND', 'UNITED KINGDOM', 'SLOVENIA', 'LIBERIA', 'PARAGUAY', 'UNITED STATES', 'ITALY', 'GEORGIA', 'SAN MARINO', 'URUGUAY', 'MONTENEGRO', 'BOSNIA AND HERZEGOVINA', 'PHILIPPINES', 'NETHERLANDS', 'POLAND', 'ICELAND', 'FINLAND', 'ECUADOR', 'CROATIA', 'CYPRUS', 'LIECHTENSTEIN', 'MALAWI', 'TUVALU', 'REPUBLIC OF KOREA', 'UKRAINE', 'SEYCHELLES', 'PORTUGAL', 'BULGARIA', 'NORWAY', 'CHAD', 'SWITZERLAND', 'REPUBLIC OF MOLDOVA', 'DENMARK', 'FIJI', 'GERMANY', 'HUNGARY', "CÔTE D'IVOIRE", 'JAPAN', 'NORTH MACEDONIA', 'ALBANIA', 'ANDORRA', 'DOMINICAN REPUBLIC', 'AUSTRIA', 'ESTONIA', 'GUATEMALA', 'BELGIUM', 'MICRONESIA (FEDERATED STATES OF)', 'PANAMA', 'MONACO', 'PERU', 'MYANMAR', 'MARSHALL ISLANDS', 'ARGENTINA', 'SLOVAKIA', 'CANADA', 'KIRIBATI', 'CHILE'}
# ______________
#
# 1
# False
#
# {'CONGO', 'ALGERIA', 'BOLIVIA (PLURINATIONAL STATE OF)', 'KAZAKHSTAN', 'TAJIKISTAN', "LAO PEOPLE'S DEMOCRATIC REPUBLIC", 'KYRGYZSTAN', 'BURUNDI', 'VIET NAM'}
# ______________
#
# 2
# False
#
# {'ANGOLA', 'MADAGASCAR'}
# ______________
#
# 3
# False
#
# {'LIBYA', 'ISRAEL', 'HAITI', 'TIMOR-LESTE', 'SIERRA LEONE', 'ANTIGUA AND BARBUDA', 'SAINT LUCIA', 'GRENADA', 'SERBIA', 'MAURITIUS', 'JAMAICA'}
# ______________
#
# 4
# False
#
# {'BAHRAIN', 'SAINT KITTS AND NEVIS', 'CAMBODIA', 'GAMBIA', 'MALAYSIA', 'YEMEN', 'BELIZE', 'JORDAN', 'GUYANA', 'EGYPT', 'OMAN', 'INDONESIA', 'BARBADOS', 'NEPAL', 'TUNISIA', 'UNITED ARAB EMIRATES', 'SAINT VINCENT AND THE GRENADINES', 'SAUDI ARABIA', 'BHUTAN', 'NIGERIA', 'SURINAME', 'BRAZIL', 'TRINIDAD AND TOBAGO'}
# ______________
#
# 5
# False
#
# {'IRAQ', 'BANGLADESH'}
# ______________
#
# 6
# False
#
# {'RUSSIAN FEDERATION', "DEMOCRATIC PEOPLE'S REPUBLIC OF KOREA", 'BELARUS', 'SYRIAN ARAB REPUBLIC'}
# ______________
#
# 7
# False
#
# {'BOTSWANA', 'BRUNEI DARUSSALAM'}
# ______________
#
# 8
# False
#
# {'MEXICO', 'KENYA', 'QATAR', 'KUWAIT', 'GHANA', 'NIGER', 'SINGAPORE', 'VANUATU', 'CABO VERDE', 'MALDIVES'}
# ______________
#
# 9
# False
#
# {'CHINA', 'CENTRAL AFRICAN REPUBLIC', 'ZIMBABWE', 'MALI', 'CUBA'}
# ______________
#
# 10
# False
#
# {'UGANDA', 'PAKISTAN', 'SOUTH AFRICA', 'SRI LANKA', 'MOZAMBIQUE', 'NAMIBIA', 'INDIA', 'MONGOLIA', 'SUDAN'}
# ______________
#
# 11
# False
#
# {'THAILAND', 'LESOTHO'}
# ______________

# %% [markdown]
# #### Связи -- единогласное голосования по всем резолюциям + те, кто один раз воздержался

# %%
figure(figsize=(20, 10))

F = G.copy()
threshold = 4
F.remove_edges_from([(n1, n2) for n1, n2, w in F.edges(data="weight") if w < threshold])
#F.remove_nodes_from([(n1) for n1, n2, w in F.edges(data="weight") if w < threshold])
#nx.draw(F)
#net_table_weight.apply(lambda x: G.add_edge(x[0], x[1], weight= x[2]), axis=1)

# Для убирания отдельных нод
F45 = nx.Graph() 
F45.add_edges_from(F.edges(data = True))

pos = nx.spring_layout(F45, seed=0)

for edge in F45.edges(data='weight'):
    nx.draw_networkx_edges(F45, pos, edgelist=[edge], width=edge[2])
       
nx.draw_networkx(F45, pos)

# %%
print(len(sorted(nx.connected_components(F45))))
print(len(F45.nodes()))
# Out:
# 9
# 158

# %%
country_name = 'RUSSIAN FEDERATION'
#country_name = 'LESOTHO'
#country_name = 'NICARAGUA'

for index in range (0, len(list(nx.connected_components(F45)))):
    print('')
    print(index)
    
    if country_name in list(nx.connected_components(F45))[index]: print('True')
    else: print('False')
        
    print('')
    
    country_arr_test = list(nx.connected_components(F45))[index]
    print(country_arr_test)
    print('______________')
# Out:
# 0
# False
#
# {'GERMANY', 'AUSTRIA', 'BULGARIA', 'SLOVAKIA', 'ALBANIA'}
# ______________
#
# 1
# False
#
# {'QATAR', 'SRI LANKA', 'EL SALVADOR', 'TURKMENISTAN', 'BURKINA FASO', 'NEPAL', 'SYRIAN ARAB REPUBLIC', 'TURKIYE', 'LIBYA', 'ECUADOR', 'PAKISTAN', 'MOZAMBIQUE', 'SAUDI ARABIA', 'INDONESIA', 'SAINT KITTS AND NEVIS', 'NIGERIA', 'MALI', 'MALAYSIA', 'CHAD', 'MAURITANIA', 'MALDIVES', 'ZAMBIA', 'GUINEA-BISSAU', 'BOTSWANA', 'SOUTH AFRICA', 'CYPRUS', 'AZERBAIJAN', 'COMOROS', 'GRENADA', 'GAMBIA', 'PHILIPPINES', 'ALGERIA', 'SAINT LUCIA', 'CHINA', 'YEMEN', 'BARBADOS', 'GABON', 'BENIN', 'UGANDA', 'GUINEA', 'MALTA', 'LESOTHO', 'NIGER', 'THAILAND', 'IRAN (ISLAMIC REPUBLIC OF)', 'KUWAIT', 'CUBA', 'OMAN', 'BHUTAN', 'KAZAKHSTAN', 'SUDAN', 'ZIMBABWE', 'SAINT VINCENT AND THE GRENADINES', 'UNITED ARAB EMIRATES', "DEMOCRATIC PEOPLE'S REPUBLIC OF KOREA", 'JAMAICA', 'NAMIBIA', 'CABO VERDE', 'LEBANON', 'BOLIVIA (PLURINATIONAL STATE OF)', 'SENEGAL', 'DJIBOUTI', 'EGYPT', "LAO PEOPLE'S DEMOCRATIC REPUBLIC", 'MOROCCO', 'KENYA', 'NICARAGUA', 'TRINIDAD AND TOBAGO', 'TUNISIA', 'JORDAN', 'MAURITIUS', 'SOLOMON ISLANDS', 'FIJI', 'BAHRAIN', 'TAJIKISTAN', 'ANGOLA', 'IRAQ', 'GUYANA', 'BRUNEI DARUSSALAM', 'ETHIOPIA', 'CAMBODIA', 'KYRGYZSTAN', 'UZBEKISTAN', 'VIET NAM', 'BANGLADESH', 'BELIZE'}
# ______________
#
# 2
# True
#
# {'RUSSIAN FEDERATION', 'SPAIN', 'FRANCE', 'ARMENIA', 'JAPAN', 'NEW ZEALAND', 'BOSNIA AND HERZEGOVINA', 'MONACO', 'COLOMBIA', 'FINLAND', 'PORTUGAL', 'POLAND', 'PARAGUAY', 'LIECHTENSTEIN', 'BELARUS', 'LATVIA', 'GEORGIA', 'ICELAND', 'BELGIUM', 'SERBIA', 'NORTH MACEDONIA', 'NORWAY', 'MONTENEGRO', 'ANDORRA', 'REPUBLIC OF KOREA', 'SLOVENIA', 'LUXEMBOURG', 'IRELAND', 'DOMINICAN REPUBLIC', 'REPUBLIC OF MOLDOVA'}
# ______________
#
# 3
# False
#
# {'SINGAPORE', 'INDIA', 'ESWATINI', "COTE D'IVOIRE", 'ARGENTINA', 'PERU'}
# ______________
#
# 4
# False
#
# {'CZECHIA', 'AUSTRALIA'}
# ______________
#
# 5
# False
#
# {'PAPUA NEW GUINEA', 'SOUTH SUDAN', 'RWANDA', 'CAMEROON', 'URUGUAY'}
# ______________
#
# 6
# False
#
# {'CANADA', 'MICRONESIA (FEDERATED STATES OF)', 'PALAU', 'NAURU', 'ISRAEL', 'MARSHALL ISLANDS', 'HUNGARY', 'UNITED STATES'}
# ______________
#
# 7
# False
#
# {'SWITZERLAND', 'ITALY', 'DENMARK', 'GREECE', 'SWEDEN', 'LITHUANIA', 'NETHERLANDS', 'ROMANIA', 'ESTONIA', 'UNITED KINGDOM', 'SAN MARINO', 'CROATIA'}
# ______________
#
# 8
# False
#
# {'MALAWI', 'MEXICO', 'PANAMA', 'TOGO'}
# ______________

# %% [markdown]
# #### Связи -- единогласное голосования по всем резолюциям + те, кто не более двух раз воздержался или один раз проголосовал против

# %%
figure(figsize=(20, 10))

F = G.copy()
threshold = 3
F.remove_edges_from([(n1, n2) for n1, n2, w in F.edges(data="weight") if w < threshold])
#F.remove_nodes_from([(n1) for n1, n2, w in F.edges(data="weight") if w < threshold])
#nx.draw(F)
#net_table_weight.apply(lambda x: G.add_edge(x[0], x[1], weight= x[2]), axis=1)

# Для убирания отдельных нод
F345 = nx.Graph() 
F345.add_edges_from(F.edges(data = True))

pos = nx.spring_layout(F345, seed=0)

for edge in F345.edges(data='weight'):
    nx.draw_networkx_edges(F345, pos, edgelist=[edge], width=edge[2])
       
nx.draw_networkx(F345, pos)

# %%
print(len(sorted(nx.connected_components(F345))))
print(len(F345.nodes()))
# Out:
# 9
# 160

# %%
country_name = 'RUSSIAN FEDERATION'
#country_name = 'LESOTHO'
#country_name = 'NICARAGUA'

for index in range (0, len(list(nx.connected_components(F345)))):
    print('')
    print(index)
    
    if country_name in list(nx.connected_components(F345))[index]: print('True')
    else: print('False')
        
    print('')
    
    country_arr_test = list(nx.connected_components(F345))[index]
    print(country_arr_test)
    print('______________')
# Out:
# 0
# False
#
# {'SPAIN', 'ROMANIA', 'LUXEMBOURG', 'LATVIA', 'CZECHIA', 'PALAU', 'SAMOA', 'AUSTRALIA', 'FRANCE', 'SWEDEN', 'TIMOR-LESTE', 'MALTA', 'COSTA RICA', 'LITHUANIA', 'GREECE', 'IRELAND', 'NEW ZEALAND', 'UNITED KINGDOM', 'SLOVENIA', 'LIBERIA', 'UNITED STATES', 'ITALY', 'SAN MARINO', 'URUGUAY', 'MONTENEGRO', 'BOSNIA AND HERZEGOVINA', 'NETHERLANDS', 'POLAND', 'CABO VERDE', 'ICELAND', 'FINLAND', 'ECUADOR', 'CROATIA', 'CYPRUS', 'LIECHTENSTEIN', 'MALAWI', 'TUVALU', 'REPUBLIC OF KOREA', 'UKRAINE', 'PORTUGAL', 'BULGARIA', 'BAHAMAS', 'NORWAY', 'SWITZERLAND', 'BARBADOS', 'REPUBLIC OF MOLDOVA', 'DENMARK', 'GERMANY', 'HUNGARY', 'JAPAN', 'ISRAEL', 'NORTH MACEDONIA', 'ALBANIA', 'ANDORRA', 'DOMINICAN REPUBLIC', 'AUSTRIA', 'ESTONIA', 'GUATEMALA', 'BELGIUM', 'MICRONESIA (FEDERATED STATES OF)', 'PANAMA', 'MONACO', 'KIRIBATI', 'MYANMAR', 'MARSHALL ISLANDS', 'ARGENTINA', 'SLOVAKIA', 'CANADA', 'SURINAME', 'CHILE'}
# ______________
#
# 1
# False
#
# {'LIBYA', 'KENYA', 'HAITI', 'SAINT KITTS AND NEVIS', 'UNITED REPUBLIC OF TANZANIA', 'GAMBIA', 'MONGOLIA', 'ZAMBIA', 'SAINT LUCIA', 'CAMEROON', 'MALAYSIA', 'GABON', 'ANGOLA', 'CONGO', 'GUINEA', 'MAURITANIA', 'MOZAMBIQUE', 'NAMIBIA', 'SINGAPORE', 'BURUNDI', 'GRENADA', 'RWANDA', 'TONGA', 'MAURITIUS', 'EGYPT', 'MADAGASCAR', 'TOGO', 'ESWATINI', 'SOUTH AFRICA', 'ANTIGUA AND BARBUDA', 'GHANA', 'NIGER', 'GUINEA-BISSAU', 'DJIBOUTI', 'NEPAL', 'TUNISIA', 'FIJI', 'UGANDA', 'UNITED ARAB EMIRATES', 'CENTRAL AFRICAN REPUBLIC', 'SOLOMON ISLANDS', 'SAINT VINCENT AND THE GRENADINES', "LAO PEOPLE'S DEMOCRATIC REPUBLIC", 'NIGERIA', 'TRINIDAD AND TOBAGO'}
# ______________
#
# 2
# False
#
# {'PAKISTAN', 'OMAN', 'SRI LANKA', 'INDONESIA', 'PHILIPPINES', 'ARMENIA', 'INDIA', 'TAJIKISTAN', 'BANGLADESH', 'KYRGYZSTAN', 'VIET NAM', 'BRUNEI DARUSSALAM', 'IRAQ'}
# ______________
#
# 3
# True
#
# {'RUSSIAN FEDERATION', 'CHINA', 'NICARAGUA', 'BELARUS', 'SYRIAN ARAB REPUBLIC', 'ZIMBABWE', "DEMOCRATIC PEOPLE'S REPUBLIC OF KOREA", 'ERITREA', 'IRAN (ISLAMIC REPUBLIC OF)', 'CUBA'}
# ______________
#
# 4
# False
#
# {'BHUTAN', 'BELIZE', 'CHAD', 'GUYANA'}
# ______________
#
# 5
# False
#
# {'MEXICO', 'COLOMBIA', 'EL SALVADOR', 'HONDURAS', 'PERU', 'BOTSWANA', 'YEMEN'}
# ______________
#
# 6
# False
#
# {"COTE D'IVOIRE", 'SENEGAL', 'THAILAND', 'JORDAN', 'BRAZIL'}
# ______________
#
# 7
# False
#
# {'KUWAIT', 'QATAR', 'PAPUA NEW GUINEA', 'JAMAICA'}
# ______________
#
# 8
# False
#
# {'KAZAKHSTAN', 'MALI'}
# ______________

# %% [markdown]
# #### Связи -- единогласное голосования по всем резолюциям + те, кто не более трех раз воздержался или ...

# %%
figure(figsize=(20, 10))

F = G.copy()
threshold = 2
F.remove_edges_from([(n1, n2) for n1, n2, w in F.edges(data="weight") if w < threshold])
#F.remove_nodes_from([(n1) for n1, n2, w in F.edges(data="weight") if w < threshold])
#nx.draw(F)
#net_table_weight.apply(lambda x: G.add_edge(x[0], x[1], weight= x[2]), axis=1)

# Для убирания отдельных нод
F2345 = nx.Graph() 
F2345.add_edges_from(F.edges(data = True))

pos = nx.spring_layout(F2345, seed=0)

for edge in F2345.edges(data='weight'):
    nx.draw_networkx_edges(F2345, pos, edgelist=[edge], width=edge[2])
       
nx.draw_networkx(F2345, pos)

# %%
print(len(sorted(nx.connected_components(F2345))))
print(len(F2345.nodes()))
# Out:
# 1
# 179

# %%
country_name = 'RUSSIAN FEDERATION'
#country_name = 'LESOTHO'
#country_name = 'NICARAGUA'

for index in range (0, len(list(nx.connected_components(F2345)))):
    print('')
    print(index)
    
    if country_name in list(nx.connected_components(F2345))[index]: print('True')
    else: print('False')
        
    print('')
    
    country_arr_test = list(nx.connected_components(F2345))[index]
    print(country_arr_test)
    print('______________')
# Out:
# 0
# True
#
# {'CHINA', 'LATVIA', 'BAHRAIN', 'SWEDEN', 'SAMOA', 'SAINT KITTS AND NEVIS', 'UNITED KINGDOM', 'COSTA RICA', 'BRUNEI DARUSSALAM', 'JAMAICA', 'PARAGUAY', 'ITALY', 'SAN MARINO', 'MOZAMBIQUE', 'NAMIBIA', 'SINGAPORE', 'POLAND', 'LIECHTENSTEIN', 'ECUADOR', 'SUDAN', 'MADAGASCAR', 'TOGO', 'PAKISTAN', 'ESWATINI', 'SOUTH AFRICA', 'REPUBLIC OF KOREA', 'INDONESIA', 'BULGARIA', 'UGANDA', 'NORTH MACEDONIA', 'NICARAGUA', 'AUSTRIA', 'EL SALVADOR', 'MOROCCO', 'BELGIUM', 'PANAMA', 'PERU', 'BHUTAN', "LAO PEOPLE'S DEMOCRATIC REPUBLIC", 'ARGENTINA', 'EQUATORIAL GUINEA', 'KIRIBATI', 'SPAIN', 'COLOMBIA', 'CAMBODIA', 'FRANCE', 'NAURU', 'GAMBIA', 'INDIA', 'LITHUANIA', 'BOTSWANA', 'GREECE', 'SAINT LUCIA', 'LIBERIA', 'CONGO', 'GUINEA', 'URUGUAY', 'MONTENEGRO', 'BURUNDI', 'AZERBAIJAN', 'TONGA', 'MALAWI', "COTE D'IVOIRE", 'OMAN', 'PORTUGAL', 'BELARUS', 'SENEGAL', "DEMOCRATIC PEOPLE'S REPUBLIC OF KOREA", 'NORWAY', 'KYRGYZSTAN', 'BARBADOS', 'NEPAL', 'CUBA', 'REPUBLIC OF MOLDOVA', 'DENMARK', 'GERMANY', 'ISRAEL', 'ESTONIA', 'GUATEMALA', 'SYRIAN ARAB REPUBLIC', 'SAUDI ARABIA', 'MARSHALL ISLANDS', 'IRAN (ISLAMIC REPUBLIC OF)', 'SURINAME', 'TRINIDAD AND TOBAGO', 'HAITI', 'PALAU', 'UNITED REPUBLIC OF TANZANIA', 'AUSTRALIA', 'BOLIVIA (PLURINATIONAL STATE OF)', 'MALTA', 'MONGOLIA', 'ZAMBIA', 'KAZAKHSTAN', 'IRELAND', 'NEW ZEALAND', 'CAMEROON', 'GABON', 'YEMEN', 'LEBANON', 'UNITED STATES', 'MAURITANIA', 'GEORGIA', 'TURKIYE', 'BOSNIA AND HERZEGOVINA', 'BRAZIL', 'TAJIKISTAN', 'CABO VERDE', 'FINLAND', 'CYPRUS', 'ALGERIA', 'BENIN', 'KUWAIT', 'ANTIGUA AND BARBUDA', 'GHANA', 'BAHAMAS', 'THAILAND', 'SWITZERLAND', 'DJIBOUTI', 'UNITED ARAB EMIRATES', 'HUNGARY', 'ALBANIA', 'ANDORRA', 'DOMINICAN REPUBLIC', 'SOLOMON ISLANDS', 'HONDURAS', 'BANGLADESH', 'NIGERIA', 'IRAQ', 'MEXICO', 'ROMANIA', 'LIBYA', 'LUXEMBOURG', 'KENYA', 'PAPUA NEW GUINEA', 'CZECHIA', 'ETHIOPIA', 'TIMOR-LESTE', 'MALAYSIA', 'ERITREA', 'VIET NAM', 'SLOVENIA', 'MALDIVES', 'ANGOLA', 'SRI LANKA', 'BELIZE', 'PHILIPPINES', 'NETHERLANDS', 'ICELAND', 'GRENADA', 'RWANDA', 'JORDAN', 'CROATIA', 'GUYANA', 'MAURITIUS', 'TUVALU', 'EGYPT', 'RUSSIAN FEDERATION', 'QATAR', 'UKRAINE', 'NIGER', 'ARMENIA', 'GUINEA-BISSAU', 'ZIMBABWE', 'UZBEKISTAN', 'CHAD', 'TUNISIA', 'FIJI', 'JAPAN', 'CENTRAL AFRICAN REPUBLIC', 'MICRONESIA (FEDERATED STATES OF)', 'SIERRA LEONE', 'SAINT VINCENT AND THE GRENADINES', 'MONACO', 'MALI', 'MYANMAR', 'SLOVAKIA', 'CANADA', 'CHILE'}
# ______________

# %%
figure(figsize=(20, 10))

F = G.copy()
threshold = 1
F.remove_edges_from([(n1, n2) for n1, n2, w in F.edges(data="weight") if w < threshold])
#F.remove_nodes_from([(n1) for n1, n2, w in F.edges(data="weight") if w < threshold])
#nx.draw(F)
#net_table_weight.apply(lambda x: G.add_edge(x[0], x[1], weight= x[2]), axis=1)

# Для убирания отдельных нод
F12345 = nx.Graph() 
F12345.add_edges_from(F.edges(data = True))

pos = nx.spring_layout(F12345, seed=0)

for edge in F12345.edges(data='weight'):
    nx.draw_networkx_edges(F12345, pos, edgelist=[edge], width=edge[2] * edge[2])
       
nx.draw_networkx(F12345, pos)

# %%
print(len(sorted(nx.connected_components(F12345))))
print(len(F12345.nodes()))
# Out:
# 1
# 183

# %% [markdown]
# ### 5. Экспорт в Gephi

# %%
topic
# Out:
# 'UKRAINE--POLITICAL CONDITIONS'

# %%
nx.write_gexf(G, "UN_{}_2023.gexf".format(topic.replace(' ', '_')))

# %% [markdown]
# ### Запись названия стран

# %%
common_table.drop(list(common_table.columns), axis = 1).to_csv('country_table.csv', index=True)
